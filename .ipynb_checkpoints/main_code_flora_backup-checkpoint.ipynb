# %%
from dotenv import load_dotenv
import os
import tradermade as tm
import pandas as pd
from pathlib import Path
import datetime as dt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler
from pandas.tseries.offsets import DateOffset

import warnings
warnings.filterwarnings('ignore')

# %%
pip install tradermade
# Out:
# Requirement already satisfied: tradermade in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (0.5.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (2.28.1)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (1.21.6)
# Requirement already satisfied: websockets==8.1 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (8.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from pandas>=0.24.2->tradermade) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from pandas>=0.24.2->tradermade) (2022.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (2022.12.7)
# Requirement already satisfied: six>=1.5 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tradermade) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# # Set environment variables from the .env in the local environment
# load_dotenv()

# %%
# # Retrieve API key and store as Python variable
# api_key = os.getenv("TRADERMADE_API_KEY")
# type(api_key)

# %%
# # set api key
# tm.set_rest_api_key(api_key)

# %% [markdown]
# # Gain Forex close price time series data from API

# %%
# # get timeseries data
# import pandas as pd
# df = pd.DataFrame()
# for i in range(2012, 2022):  
#     x = tm.timeseries(currency='AUDUSD', start=str(i)+"-12-01",fields=["open", "high", "low","close"], end=str(i+1)+"-11-30")
#     df = df.append(x)
# df = df.drop_duplicates()
# df
# # returns timeseries data for the currency requested interval is daily, hourly, minute - fields parameter is optional (you can select ["close"] if you just want close prices)

# %%
# df.index = pd.to_datetime(df['date'])

# %%
# df = df.drop(columns = "date")
# df

# %%
# close_daily = df.drop(columns=["open", "high", "low"])

# %%
# close_daily

# %%
# close_daily_reset_index.to_csv('close_daily_reset_index.csv', encoding='utf-8', index=True)

# %%
# Read in daily close price csv file into dataframe
path_close_daily = "./Resources/close_daily.csv"
close_daily = pd.read_csv(path_close_daily, parse_dates = True, infer_datetime_format = True, index_col = "date")
close_daily
# Out:
#               close
# date
# 2012-12-03  1.04220
# 2012-12-04  1.04710
# 2012-12-05  1.04560
# 2012-12-06  1.04870
# 2012-12-07  1.04890
# ...             ...
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
# 2022-11-30  0.67880
#
# [2608 rows x 1 columns]

# %% [markdown]
# # Read US unemployment rate data from csv file to a dataframe, convert the data into time series and slice the data from Dec 2012 to Nov 2022

# %%
# read us unemployment rate csv file into dataframe
path_str_us = "./Resources/US-Unemployment rate-2012 to 2022.csv"
path_us = Path(path_str_us)
data_us = pd.read_csv(path_us, parse_dates = True,infer_datetime_format = True)
data_us
# Out:
#     Year  Jan  Feb  Mar   Apr   May   Jun   Jul  Aug  Sep  Oct  Nov  Dec
# 0   2012  8.3  8.3  8.2   8.2   8.2   8.2   8.2  8.1  7.8  7.8  7.7  7.9
# 1   2013  8.0  7.7  7.5   7.6   7.5   7.5   7.3  7.2  7.2  7.2  6.9  6.7
# 2   2014  6.6  6.7  6.7   6.2   6.3   6.1   6.2  6.1  5.9  5.7  5.8  5.6
# 3   2015  5.7  5.5  5.4   5.4   5.6   5.3   5.2  5.1  5.0  5.0  5.1  5.0
# 4   2016  4.8  4.9  5.0   5.1   4.8   4.9   4.8  4.9  5.0  4.9  4.7  4.7
# 5   2017  4.7  4.6  4.4   4.4   4.4   4.3   4.3  4.4  4.3  4.2  4.2  4.1
# 6   2018  4.0  4.1  4.0   4.0   3.8   4.0   3.8  3.8  3.7  3.8  3.8  3.9
# 7   2019  4.0  3.8  3.8   3.6   3.6   3.6   3.7  3.7  3.5  3.6  3.6  3.6
# 8   2020  3.5  3.5  4.4  14.7  13.2  11.0  10.2  8.4  7.9  6.9  6.7  6.7
# 9   2021  6.4  6.2  6.0   6.0   5.8   5.9   5.4  5.2  4.7  4.6  4.2  3.9
# 10  2022  4.0  3.8  3.6   3.6   3.6   3.6   3.5  3.7  3.5  3.7  3.7  NaN

# %%
# convert to 1 dimension time series data
new_data_us=data_us.set_index('Year')
df1_us=new_data_us.stack()
df1_us
# Out:
# Year
# 2012  Jan    8.3
#       Feb    8.3
#       Mar    8.2
#       Apr    8.2
#       May    8.2
#             ...
# 2022  Jul    3.5
#       Aug    3.7
#       Sep    3.5
#       Oct    3.7
#       Nov    3.7
# Length: 131, dtype: float64

# %%
df2_us=df1_us.reset_index()
df2_us
# Out:
#      Year level_1    0
# 0    2012     Jan  8.3
# 1    2012     Feb  8.3
# 2    2012     Mar  8.2
# 3    2012     Apr  8.2
# 4    2012     May  8.2
# ..    ...     ...  ...
# 126  2022     Jul  3.5
# 127  2022     Aug  3.7
# 128  2022     Sep  3.5
# 129  2022     Oct  3.7
# 130  2022     Nov  3.7
#
# [131 rows x 3 columns]

# %%
# Rename columns' name
df2_us.columns = ['Year','Month','us_rate']
df2_us
# Out:
#      Year Month  us_rate
# 0    2012   Jan      8.3
# 1    2012   Feb      8.3
# 2    2012   Mar      8.2
# 3    2012   Apr      8.2
# 4    2012   May      8.2
# ..    ...   ...      ...
# 126  2022   Jul      3.5
# 127  2022   Aug      3.7
# 128  2022   Sep      3.5
# 129  2022   Oct      3.7
# 130  2022   Nov      3.7
#
# [131 rows x 3 columns]

# %%
# Slice the data to Dec 2012 to Nov 2022 period
df3_us= df2_us[11:]
df3_us=df3_us.reset_index()
df3_us
# Out:
#      index  Year Month  us_rate
# 0       11  2012   Dec      7.9
# 1       12  2013   Jan      8.0
# 2       13  2013   Feb      7.7
# 3       14  2013   Mar      7.5
# 4       15  2013   Apr      7.6
# ..     ...   ...   ...      ...
# 115    126  2022   Jul      3.5
# 116    127  2022   Aug      3.7
# 117    128  2022   Sep      3.5
# 118    129  2022   Oct      3.7
# 119    130  2022   Nov      3.7
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe
df3_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    120 non-null    int64
#  1   Year     120 non-null    int64
#  2   Month    120 non-null    object
#  3   us_rate  120 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
df_us=df3_us.drop(columns=['index','Year','Month'])
df_us
# Out:
#      us_rate
# 0        7.9
# 1        8.0
# 2        7.7
# 3        7.5
# 4        7.6
# ..       ...
# 115      3.5
# 116      3.7
# 117      3.5
# 118      3.7
# 119      3.7
#
# [120 rows x 1 columns]

# %% [markdown]
# # Read AU unemployment rate data from csv file to a dataframe, slice the data from Dec 2012 to Nov 2022

# %%
# Read au unemployment data from csv file to dataframe
path_str_au = "./Resources/AU-Unemployment rate-2012 to 2022.csv"
path_au = Path(path_str_au)
data_au = pd.read_csv(path_au, parse_dates = True,infer_datetime_format = True)
data_au
# Out:
#                                             Unnamed: 0  Trend (%)  \
# 0                                               Nov-12        5.4
# 1                                               Dec-12        5.4
# 2                                               Jan-13        5.4
# 3                                               Feb-13        5.5
# 4                                               Mar-13        5.6
# ..                                                 ...        ...
# 120                                             Nov-22        3.5
# 121                                                NaN        NaN
# 122  Large month-to-month changes occurred during t...        NaN
# 123                                                NaN        NaN
# 124  Source: Australian Bureau of Statistics, Labou...        NaN
#
#      Seasonally adjusted (%)
# 0                        5.3
# 1                        5.4
# 2                        5.4
# 3                        5.4
# 4                        5.6
# ..                       ...
# 120                      3.4
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
#
# [125 rows x 3 columns]

# %%
# Slice the data from Dec 2012
data_au=data_au[1:121]
data_au
# Out:
#     Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 1       Dec-12        5.4                      5.4
# 2       Jan-13        5.4                      5.4
# 3       Feb-13        5.5                      5.4
# 4       Mar-13        5.6                      5.6
# 5       Apr-13        5.6                      5.6
# ..         ...        ...                      ...
# 116     Jul-22        3.6                      3.5
# 117     Aug-22        3.5                      3.5
# 118     Sep-22        3.5                      3.6
# 119     Oct-22        3.5                      3.4
# 120     Nov-22        3.5                      3.4
#
# [120 rows x 3 columns]

# %%
# Drop null data and slice the data from Dec 2012 to Nov 2022
data_au=data_au.reset_index()
data_au
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 0        1     Dec-12        5.4                      5.4
# 1        2     Jan-13        5.4                      5.4
# 2        3     Feb-13        5.5                      5.4
# 3        4     Mar-13        5.6                      5.6
# 4        5     Apr-13        5.6                      5.6
# ..     ...        ...        ...                      ...
# 115    116     Jul-22        3.6                      3.5
# 116    117     Aug-22        3.5                      3.5
# 117    118     Sep-22        3.5                      3.6
# 118    119     Oct-22        3.5                      3.4
# 119    120     Nov-22        3.5                      3.4
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe, since the data in trend column has null data, we will use seasonally adjusted data for the unemployment rates
data_au.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    120 non-null    int64
#  1   Unnamed: 0               120 non-null    object
#  2   Trend (%)                96 non-null     float64
#  3   Seasonally adjusted (%)  120 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
# Rename columns' name
data_au_rate=data_au.drop(columns=['index','Unnamed: 0','Trend (%)'])

data_au_rate.columns= ['au_rate']
data_au_rate
# Out:
#      au_rate
# 0        5.4
# 1        5.4
# 2        5.4
# 3        5.6
# 4        5.6
# ..       ...
# 115      3.5
# 116      3.5
# 117      3.6
# 118      3.4
# 119      3.4
#
# [120 rows x 1 columns]

# %%
us_au_unemployment_df = pd.concat([data_au_rate,df_us],axis=1)

# %%
us_au_unemployment_df
# Out:
#      au_rate  us_rate
# 0        5.4      7.9
# 1        5.4      8.0
# 2        5.4      7.7
# 3        5.6      7.5
# 4        5.6      7.6
# ..       ...      ...
# 115      3.5      3.5
# 116      3.5      3.7
# 117      3.6      3.5
# 118      3.4      3.7
# 119      3.4      3.7
#
# [120 rows x 2 columns]

# %%
#Check if the data is valid
us_au_unemployment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   au_rate  120 non-null    float64
#  1   us_rate  120 non-null    float64
# dtypes: float64(2)
# memory usage: 2.0 KB

# %%
us_au_unemployment_df['us/au unemployment ratio']=us_au_unemployment_df['us_rate']/us_au_unemployment_df['au_rate']

# %%
us_au_unemployment_df
# Out:
#      au_rate  us_rate  us/au unemployment ratio
# 0        5.4      7.9                  1.462963
# 1        5.4      8.0                  1.481481
# 2        5.4      7.7                  1.425926
# 3        5.6      7.5                  1.339286
# 4        5.6      7.6                  1.357143
# ..       ...      ...                       ...
# 115      3.5      3.5                  1.000000
# 116      3.5      3.7                  1.057143
# 117      3.6      3.5                  0.972222
# 118      3.4      3.7                  1.088235
# 119      3.4      3.7                  1.088235
#
# [120 rows x 3 columns]

# %% [markdown]
# # Change the dataframe into daily data for daily fx rate prediction

# %% [markdown]
# ## Convert US unemployment data into daily data

# %%
# Set another column for the day and refill it with the same monthly data

df3_us_daily=df3_us
df3_us_daily['Day'] = '1'


# Add another column for the date

df3_us_daily['Date'] = df3_us_daily[['Year','Month', 'Day']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")

df3_us_daily
# Out:
#      index  Year Month  us_rate Day        Date
# 0       11  2012   Dec      7.9   1  2012-Dec-1
# 1       12  2013   Jan      8.0   1  2013-Jan-1
# 2       13  2013   Feb      7.7   1  2013-Feb-1
# 3       14  2013   Mar      7.5   1  2013-Mar-1
# 4       15  2013   Apr      7.6   1  2013-Apr-1
# ..     ...   ...   ...      ...  ..         ...
# 115    126  2022   Jul      3.5   1  2022-Jul-1
# 116    127  2022   Aug      3.7   1  2022-Aug-1
# 117    128  2022   Sep      3.5   1  2022-Sep-1
# 118    129  2022   Oct      3.7   1  2022-Oct-1
# 119    130  2022   Nov      3.7   1  2022-Nov-1
#
# [120 rows x 6 columns]

# %%
# set the last datetime in order to get full 10 year data
df3_us_daily['Date'].iloc[-1]='2022-Nov-30'
df3_us_daily
# Out:
#      index  Year Month  us_rate Day         Date
# 0       11  2012   Dec      7.9   1   2012-Dec-1
# 1       12  2013   Jan      8.0   1   2013-Jan-1
# 2       13  2013   Feb      7.7   1   2013-Feb-1
# 3       14  2013   Mar      7.5   1   2013-Mar-1
# 4       15  2013   Apr      7.6   1   2013-Apr-1
# ..     ...   ...   ...      ...  ..          ...
# 115    126  2022   Jul      3.5   1   2022-Jul-1
# 116    127  2022   Aug      3.7   1   2022-Aug-1
# 117    128  2022   Sep      3.5   1   2022-Sep-1
# 118    129  2022   Oct      3.7   1   2022-Oct-1
# 119    130  2022   Nov      3.7   1  2022-Nov-30
#
# [120 rows x 6 columns]

# %%
# Check if there is no null data in the dataframe
df3_us_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    120 non-null    int64
#  1   Year     120 non-null    int64
#  2   Month    120 non-null    object
#  3   us_rate  120 non-null    float64
#  4   Day      120 non-null    object
#  5   Date     120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
# change to datetime format
df3_us_daily['Date']=pd.to_datetime(df3_us_daily['Date'])
df3_us_daily['Date']
# Out:
# 0     2012-12-01
# 1     2013-01-01
# 2     2013-02-01
# 3     2013-03-01
# 4     2013-04-01
#          ...
# 115   2022-07-01
# 116   2022-08-01
# 117   2022-09-01
# 118   2022-10-01
# 119   2022-11-30
# Name: Date, Length: 120, dtype: datetime64[ns]

# %%
# Resample and convert to daily data
new_df3_us_daily=df3_us_daily.set_index('Date').resample('D').ffill()
new_df3_us_daily
# Out:
#             index  Year Month  us_rate Day
# Date
# 2012-12-01     11  2012   Dec      7.9   1
# 2012-12-02     11  2012   Dec      7.9   1
# 2012-12-03     11  2012   Dec      7.9   1
# 2012-12-04     11  2012   Dec      7.9   1
# 2012-12-05     11  2012   Dec      7.9   1
# ...           ...   ...   ...      ...  ..
# 2022-11-26    129  2022   Oct      3.7   1
# 2022-11-27    129  2022   Oct      3.7   1
# 2022-11-28    129  2022   Oct      3.7   1
# 2022-11-29    129  2022   Oct      3.7   1
# 2022-11-30    130  2022   Nov      3.7   1
#
# [3652 rows x 5 columns]

# %%
# Drop unnecessary columns
new_df3_us_daily=new_df3_us_daily.drop(columns=['index','Year','Month','Day'])
new_df3_us_daily
# Out:
#             us_rate
# Date
# 2012-12-01      7.9
# 2012-12-02      7.9
# 2012-12-03      7.9
# 2012-12-04      7.9
# 2012-12-05      7.9
# ...             ...
# 2022-11-26      3.7
# 2022-11-27      3.7
# 2022-11-28      3.7
# 2022-11-29      3.7
# 2022-11-30      3.7
#
# [3652 rows x 1 columns]

# %%
# Rename the column
new_df3_us_daily.columns=['us_unemployment_rate']
new_df3_us_daily.head(120)
# Out:
#             us_unemployment_rate
# Date
# 2012-12-01                   7.9
# 2012-12-02                   7.9
# 2012-12-03                   7.9
# 2012-12-04                   7.9
# 2012-12-05                   7.9
# ...                          ...
# 2013-03-26                   7.5
# 2013-03-27                   7.5
# 2013-03-28                   7.5
# 2013-03-29                   7.5
# 2013-03-30                   7.5
#
# [120 rows x 1 columns]

# %% [markdown]
# ## Convert AU unemployment data into daily data

# %%
data_au
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 0        1     Dec-12        5.4                      5.4
# 1        2     Jan-13        5.4                      5.4
# 2        3     Feb-13        5.5                      5.4
# 3        4     Mar-13        5.6                      5.6
# 4        5     Apr-13        5.6                      5.6
# ..     ...        ...        ...                      ...
# 115    116     Jul-22        3.6                      3.5
# 116    117     Aug-22        3.5                      3.5
# 117    118     Sep-22        3.5                      3.6
# 118    119     Oct-22        3.5                      3.4
# 119    120     Nov-22        3.5                      3.4
#
# [120 rows x 4 columns]

# %%
# Set another column for the day and refill it with the same monthly data

data_au_daily=data_au
data_au_daily['Day'] = '1'


# Add another column for the date

data_au_daily['Date'] = data_au_daily[['Day','Unnamed: 0']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")

data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day      Date
# 0        1     Dec-12        5.4                      5.4   1  1-Dec-12
# 1        2     Jan-13        5.4                      5.4   1  1-Jan-13
# 2        3     Feb-13        5.5                      5.4   1  1-Feb-13
# 3        4     Mar-13        5.6                      5.6   1  1-Mar-13
# 4        5     Apr-13        5.6                      5.6   1  1-Apr-13
# ..     ...        ...        ...                      ...  ..       ...
# 115    116     Jul-22        3.6                      3.5   1  1-Jul-22
# 116    117     Aug-22        3.5                      3.5   1  1-Aug-22
# 117    118     Sep-22        3.5                      3.6   1  1-Sep-22
# 118    119     Oct-22        3.5                      3.4   1  1-Oct-22
# 119    120     Nov-22        3.5                      3.4   1  1-Nov-22
#
# [120 rows x 6 columns]

# %%
# set the last date in order to get the full 10 year period of data
data_au_daily['Date'].iloc[-1]='30-Nov-22'
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1   1-Dec-12
# 1        2     Jan-13        5.4                      5.4   1   1-Jan-13
# 2        3     Feb-13        5.5                      5.4   1   1-Feb-13
# 3        4     Mar-13        5.6                      5.6   1   1-Mar-13
# 4        5     Apr-13        5.6                      5.6   1   1-Apr-13
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1   1-Jul-22
# 116    117     Aug-22        3.5                      3.5   1   1-Aug-22
# 117    118     Sep-22        3.5                      3.6   1   1-Sep-22
# 118    119     Oct-22        3.5                      3.4   1   1-Oct-22
# 119    120     Nov-22        3.5                      3.4   1  30-Nov-22
#
# [120 rows x 6 columns]

# %%
# Change to datetime format
data_au_daily['Date']=pd.to_datetime(data_au_daily['Date'])
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1 2012-12-01
# 1        2     Jan-13        5.4                      5.4   1 2013-01-01
# 2        3     Feb-13        5.5                      5.4   1 2013-02-01
# 3        4     Mar-13        5.6                      5.6   1 2013-03-01
# 4        5     Apr-13        5.6                      5.6   1 2013-04-01
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1 2022-07-01
# 116    117     Aug-22        3.5                      3.5   1 2022-08-01
# 117    118     Sep-22        3.5                      3.6   1 2022-09-01
# 118    119     Oct-22        3.5                      3.4   1 2022-10-01
# 119    120     Nov-22        3.5                      3.4   1 2022-11-30
#
# [120 rows x 6 columns]

# %%
# Resample and convert to daily data
new_data_au_daily=data_au_daily.set_index('Date').resample('D').ffill()
new_data_au_daily
# Out:
#             index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day
# Date
# 2012-12-01      1     Dec-12        5.4                      5.4   1
# 2012-12-02      1     Dec-12        5.4                      5.4   1
# 2012-12-03      1     Dec-12        5.4                      5.4   1
# 2012-12-04      1     Dec-12        5.4                      5.4   1
# 2012-12-05      1     Dec-12        5.4                      5.4   1
# ...           ...        ...        ...                      ...  ..
# 2022-11-26    119     Oct-22        3.5                      3.4   1
# 2022-11-27    119     Oct-22        3.5                      3.4   1
# 2022-11-28    119     Oct-22        3.5                      3.4   1
# 2022-11-29    119     Oct-22        3.5                      3.4   1
# 2022-11-30    120     Nov-22        3.5                      3.4   1
#
# [3652 rows x 5 columns]

# %%
# Check the data
new_data_au_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 2012-12-01 to 2022-11-30
# Freq: D
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    3652 non-null   int64
#  1   Unnamed: 0               3652 non-null   object
#  2   Trend (%)                2922 non-null   float64
#  3   Seasonally adjusted (%)  3652 non-null   float64
#  4   Day                      3652 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 171.2+ KB

# %%
# Drop unnecessary columns
new_data_au_daily=new_data_au_daily.drop(columns=['index','Unnamed: 0','Trend (%)','Day'])
new_data_au_daily
# Out:
#             Seasonally adjusted (%)
# Date
# 2012-12-01                      5.4
# 2012-12-02                      5.4
# 2012-12-03                      5.4
# 2012-12-04                      5.4
# 2012-12-05                      5.4
# ...                             ...
# 2022-11-26                      3.4
# 2022-11-27                      3.4
# 2022-11-28                      3.4
# 2022-11-29                      3.4
# 2022-11-30                      3.4
#
# [3652 rows x 1 columns]

# %%
# Rename the column
new_data_au_daily.columns=['au_unemployment_rate']
new_data_au_daily.head(120)
# Out:
#             au_unemployment_rate
# Date
# 2012-12-01                   5.4
# 2012-12-02                   5.4
# 2012-12-03                   5.4
# 2012-12-04                   5.4
# 2012-12-05                   5.4
# ...                          ...
# 2013-03-26                   5.6
# 2013-03-27                   5.6
# 2013-03-28                   5.6
# 2013-03-29                   5.6
# 2013-03-30                   5.6
#
# [120 rows x 1 columns]

# %% [markdown]
# # Read in USD Index Daily data into dataframe

# %%
# Reading USA Index Daily Data into dataframe from USD_index_data.csv
df_us_index_data = pd.read_csv("USD_index_data.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True,dayfirst=True)                   
df_us_index_data
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2012-12-03   80.180000   80.269997   79.800003   79.879997   79.879997     0.0
# 2012-12-04   79.889999   80.190002   79.610001   79.639999   79.639999     0.0
# 2012-12-05   79.589996   79.919998   79.570000   79.769997   79.769997     0.0
# 2012-12-06   79.800003   80.320000   79.570000   80.260002   80.260002     0.0
# 2012-12-07   80.269997   80.660004   79.730003   80.419998   80.419998     0.0
# ...                ...         ...         ...         ...         ...     ...
# 2022-11-24  105.989998  106.070000  105.629997  105.849998  105.849998     0.0
# 2022-11-25  105.959999  106.419998  105.690002  105.959999  105.959999     0.0
# 2022-11-27         NaN         NaN         NaN         NaN         NaN     NaN
# 2022-11-28  106.059998  106.750000  105.320000  106.680000  106.680000     0.0
# 2022-11-29  106.570000  106.879997  106.059998  106.820000  106.820000     0.0
#
# [3044 rows x 6 columns]

# %%
df_us_index_data=df_us_index_data.dropna()
df_us_index_data=df_us_index_data[['Close']]
df_us_index_data
# Out:
#                  Close
# Date
# 2012-12-03   79.879997
# 2012-12-04   79.639999
# 2012-12-05   79.769997
# 2012-12-06   80.260002
# 2012-12-07   80.419998
# ...                ...
# 2022-11-23  106.080002
# 2022-11-24  105.849998
# 2022-11-25  105.959999
# 2022-11-28  106.680000
# 2022-11-29  106.820000
#
# [2519 rows x 1 columns]

# %%
df_us_index_data=df_us_index_data['2012-12-03':]
df_us_index_data
# Out:
#                  Close
# Date
# 2012-12-03   79.879997
# 2012-12-04   79.639999
# 2012-12-05   79.769997
# 2012-12-06   80.260002
# 2012-12-07   80.419998
# ...                ...
# 2022-11-23  106.080002
# 2022-11-24  105.849998
# 2022-11-25  105.959999
# 2022-11-28  106.680000
# 2022-11-29  106.820000
#
# [2519 rows x 1 columns]

# %%
df_us_index_data.columns=['us_index_daily_data']
df_us_index_data
# Out:
#             us_index_daily_data
# Date
# 2012-12-03            79.879997
# 2012-12-04            79.639999
# 2012-12-05            79.769997
# 2012-12-06            80.260002
# 2012-12-07            80.419998
# ...                         ...
# 2022-11-23           106.080002
# 2022-11-24           105.849998
# 2022-11-25           105.959999
# 2022-11-28           106.680000
# 2022-11-29           106.820000
#
# [2519 rows x 1 columns]

# %% [markdown]
# # Read in USA inflation rate

# %%
# # Reading USA inflation rate from USA_Inflation_Rate.csv
# df_us_inflation = pd.read_csv("./Resources/USA_Inflation_Rate.csv",
#                              index_col = "Date",
#                               infer_datetime_format=True,
#                              parse_dates=True)                   
# df_us_inflation

# %%
# # Reading USA inflation rate from us-inflation-rate-flora.csv
df_us_inflation = pd.read_csv("./Resources/us-inflation-rate-flora.csv")                   
df_us_inflation
# Out:
#     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  NOV  DEC
# 0   2012  2.9  2.9  2.7  2.3  1.7  1.7  1.4  1.7  2.0  2.2  1.8  1.7
# 1   2013  1.6  2.0  1.5  1.1  1.4  1.8  2.0  1.5  1.2  1.0  1.2  1.5
# 2   2014  1.6  1.1  1.5  2.0  2.1  2.1  2.0  1.7  1.7  1.7  1.3  0.8
# 3   2015 -0.1  0.0 -0.1 -0.2  0.0  0.1  0.2  0.2  0.0  0.2  0.5  0.7
# 4   2016  1.4  1.0  0.9  1.1  1.0  1.0  0.8  1.1  1.5  1.6  1.7  2.1
# 5   2017  2.5  2.7  2.4  2.2  1.9  1.6  1.7  1.9  2.2  2.0  2.2  2.1
# 6   2018  2.1  2.2  2.4  2.5  2.8  2.9  2.9  2.7  2.3  2.5  2.2  1.9
# 7   2019  1.6  1.5  1.9  2.0  1.8  1.6  1.8  1.7  1.7  1.8  2.1  2.3
# 8   2020  2.5  2.3  1.5  0.3  0.1  0.6  1.0  1.3  1.4  1.2  1.2  1.4
# 9   2021  1.4  1.7  2.6  4.2  5.0  5.4  5.4  5.3  5.4  6.2  6.8  7.0
# 10  2022  7.5  7.9  8.5  8.3  8.6  9.1  8.5  8.3  8.2  7.7  7.1  NaN

# %%
# convert to 1 dimension time series data
new_data_us_inflation=df_us_inflation.set_index('YEAR')
df1_us_inflation=new_data_us_inflation.stack()
df1_us_inflation
# Out:
# YEAR
# 2012  JAN    2.9
#       FEB    2.9
#       MAR    2.7
#       APR    2.3
#       MAY    1.7
#             ...
# 2022  JUL    8.5
#       AUG    8.3
#       SEP    8.2
#       OCT    7.7
#       NOV    7.1
# Length: 131, dtype: float64

# %%
df2_us_inflation=df1_us_inflation.reset_index()
df2_us_inflation
# Out:
#      YEAR level_1    0
# 0    2012     JAN  2.9
# 1    2012     FEB  2.9
# 2    2012     MAR  2.7
# 3    2012     APR  2.3
# 4    2012     MAY  1.7
# ..    ...     ...  ...
# 126  2022     JUL  8.5
# 127  2022     AUG  8.3
# 128  2022     SEP  8.2
# 129  2022     OCT  7.7
# 130  2022     NOV  7.1
#
# [131 rows x 3 columns]

# %%
# Rename columns' name
df2_us_inflation.columns = ['Year','Month','us_inflation_rate']
df2_us_inflation
# Out:
#      Year Month  us_inflation_rate
# 0    2012   JAN                2.9
# 1    2012   FEB                2.9
# 2    2012   MAR                2.7
# 3    2012   APR                2.3
# 4    2012   MAY                1.7
# ..    ...   ...                ...
# 126  2022   JUL                8.5
# 127  2022   AUG                8.3
# 128  2022   SEP                8.2
# 129  2022   OCT                7.7
# 130  2022   NOV                7.1
#
# [131 rows x 3 columns]

# %%
# Slice the data to Dec 2012 to Nov 2022 period
df3_us_inflation= df2_us_inflation[11:]
df3_us_inflation=df3_us_inflation.reset_index()
df3_us_inflation
# Out:
#      index  Year Month  us_inflation_rate
# 0       11  2012   DEC                1.7
# 1       12  2013   JAN                1.6
# 2       13  2013   FEB                2.0
# 3       14  2013   MAR                1.5
# 4       15  2013   APR                1.1
# ..     ...   ...   ...                ...
# 115    126  2022   JUL                8.5
# 116    127  2022   AUG                8.3
# 117    128  2022   SEP                8.2
# 118    129  2022   OCT                7.7
# 119    130  2022   NOV                7.1
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe
df3_us_inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              120 non-null    int64
#  1   Year               120 non-null    int64
#  2   Month              120 non-null    object
#  3   us_inflation_rate  120 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
df_us_inflation=df3_us_inflation.drop(columns=['index','Year','Month'])
df_us_inflation
# Out:
#      us_inflation_rate
# 0                  1.7
# 1                  1.6
# 2                  2.0
# 3                  1.5
# 4                  1.1
# ..                 ...
# 115                8.5
# 116                8.3
# 117                8.2
# 118                7.7
# 119                7.1
#
# [120 rows x 1 columns]

# %%
# Convert to daily data by resampling

# %%
# Set another column for the day and refill it with the same monthly data

df3_us_daily_inflation=df3_us_inflation
df3_us_daily_inflation['Day'] = '1'


# Add another column for the date

df3_us_daily_inflation['Date'] = df3_us_daily_inflation[['Year','Month', 'Day']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")

df3_us_daily_inflation
# Out:
#      index  Year Month  us_inflation_rate Day        Date
# 0       11  2012   DEC                1.7   1  2012-DEC-1
# 1       12  2013   JAN                1.6   1  2013-JAN-1
# 2       13  2013   FEB                2.0   1  2013-FEB-1
# 3       14  2013   MAR                1.5   1  2013-MAR-1
# 4       15  2013   APR                1.1   1  2013-APR-1
# ..     ...   ...   ...                ...  ..         ...
# 115    126  2022   JUL                8.5   1  2022-JUL-1
# 116    127  2022   AUG                8.3   1  2022-AUG-1
# 117    128  2022   SEP                8.2   1  2022-SEP-1
# 118    129  2022   OCT                7.7   1  2022-OCT-1
# 119    130  2022   NOV                7.1   1  2022-NOV-1
#
# [120 rows x 6 columns]

# %%
# set the last datetime in order to get full 10 year data
df3_us_daily_inflation['Date'].iloc[-1]='2022-Nov-30'
df3_us_daily_inflation
# Out:
#      index  Year Month  us_inflation_rate Day         Date
# 0       11  2012   DEC                1.7   1   2012-DEC-1
# 1       12  2013   JAN                1.6   1   2013-JAN-1
# 2       13  2013   FEB                2.0   1   2013-FEB-1
# 3       14  2013   MAR                1.5   1   2013-MAR-1
# 4       15  2013   APR                1.1   1   2013-APR-1
# ..     ...   ...   ...                ...  ..          ...
# 115    126  2022   JUL                8.5   1   2022-JUL-1
# 116    127  2022   AUG                8.3   1   2022-AUG-1
# 117    128  2022   SEP                8.2   1   2022-SEP-1
# 118    129  2022   OCT                7.7   1   2022-OCT-1
# 119    130  2022   NOV                7.1   1  2022-Nov-30
#
# [120 rows x 6 columns]

# %%
# Check if there is no null data in the dataframe
df3_us_daily_inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              120 non-null    int64
#  1   Year               120 non-null    int64
#  2   Month              120 non-null    object
#  3   us_inflation_rate  120 non-null    float64
#  4   Day                120 non-null    object
#  5   Date               120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
# change to datetime format
df3_us_daily_inflation['Date']=pd.to_datetime(df3_us_daily_inflation['Date'])
df3_us_daily_inflation['Date']
# Out:
# 0     2012-12-01
# 1     2013-01-01
# 2     2013-02-01
# 3     2013-03-01
# 4     2013-04-01
#          ...
# 115   2022-07-01
# 116   2022-08-01
# 117   2022-09-01
# 118   2022-10-01
# 119   2022-11-30
# Name: Date, Length: 120, dtype: datetime64[ns]

# %%
# Resample and convert to daily data
new_df3_us_daily_inflation=df3_us_daily_inflation.set_index('Date').resample('D').ffill().reset_index()
new_df3_us_daily_inflation=new_df3_us_daily_inflation.drop(columns=['index','Year','Month','Day'])
new_df3_us_daily_inflation
# Out:
#            Date  us_inflation_rate
# 0    2012-12-01                1.7
# 1    2012-12-02                1.7
# 2    2012-12-03                1.7
# 3    2012-12-04                1.7
# 4    2012-12-05                1.7
# ...         ...                ...
# 3647 2022-11-26                7.7
# 3648 2022-11-27                7.7
# 3649 2022-11-28                7.7
# 3650 2022-11-29                7.7
# 3651 2022-11-30                7.1
#
# [3652 rows x 2 columns]

# %%
new_df3_us_daily_inflation=new_df3_us_daily_inflation.set_index('Date')
new_df3_us_daily_inflation
# Out:
#             us_inflation_rate
# Date
# 2012-12-01                1.7
# 2012-12-02                1.7
# 2012-12-03                1.7
# 2012-12-04                1.7
# 2012-12-05                1.7
# ...                       ...
# 2022-11-26                7.7
# 2022-11-27                7.7
# 2022-11-28                7.7
# 2022-11-29                7.7
# 2022-11-30                7.1
#
# [3652 rows x 1 columns]

# %%
# #resampling the data with daily with .ffill function  
# df_us_inflation_daily=df_us_inflation.resample('D').ffill()
# df_us_inflation_daily

# %%
# # selected data range from 2012-12-01  to 2022-11-30
# df_us_inflation_daily = df_us_inflation_daily.loc["2012-12-01":"2022-11-30"]
# df_us_inflation_daily

# %%
# # Rename the column
# df_us_inflation_daily.columns=['us_inflation_rate']
# df_us_inflation_daily.head(120)

# %%
# Reading USA fed rate from fed-funds-rate-historical-chart.csv

df_us_fed_rate = pd.read_csv("./Resources/fed-funds-rate-historical-chart.csv", 
                             index_col = "date",
                             infer_datetime_format=True,
                             parse_dates=True)

# %%
#resampling the data with daily with .ffill function  
df_us_fed_rate_daily=df_us_fed_rate.resample('D').ffill()
df_us_fed_rate_daily
# Out:
#              value
# date
# 1954-07-01    1.13
# 1954-07-02    1.25
# 1954-07-03    1.25
# 1954-07-04    1.25
# 1954-07-05    0.88
# ...            ...
# 2022-12-18    4.33
# 2022-12-19    4.33
# 2022-12-20    4.33
# 2022-12-21    4.33
# 2022-12-22    4.33
#
# [25012 rows x 1 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_us_fed_rate_daily = df_us_fed_rate_daily.loc["2012-12-1":"2022-11-30"]
df_us_fed_rate_daily
# Out:
#              value
# date
# 2012-12-01    0.16
# 2012-12-02    0.16
# 2012-12-03    0.16
# 2012-12-04    0.17
# 2012-12-05    0.16
# ...            ...
# 2022-11-26    3.83
# 2022-11-27    3.83
# 2022-11-28    3.83
# 2022-11-29    3.83
# 2022-11-30    3.83
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_us_fed_rate_daily.columns=['us_fed_rate']
df_us_fed_rate_daily.head(120)
# Out:
#             us_fed_rate
# date
# 2012-12-01         0.16
# 2012-12-02         0.16
# 2012-12-03         0.16
# 2012-12-04         0.17
# 2012-12-05         0.16
# ...                 ...
# 2013-03-26         0.14
# 2013-03-27         0.12
# 2013-03-28         0.13
# 2013-03-29         0.09
# 2013-03-30         0.09
#
# [120 rows x 1 columns]

# %%
# Reading AU inflation rate from AU_Inflation.csv file
df_au_inflation_rate = pd.read_csv("./Resources/AU_Inflation.csv",
                            index_col = "Date",
                             infer_datetime_format=True,
                             parse_dates=True)
df_au_inflation_rate
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-12-01          7.8         NaN
# 1990-03-01          8.7         NaN
# 1990-06-01          7.7         NaN
# 1990-09-01          6.1         NaN
# ...                 ...         ...
# 2022-09-21          3.0         2.1
# 2022-12-21          3.5         2.6
# 2022-03-22          5.1         3.7
# 2022-06-22          6.1         4.9
# 2022-09-22          7.3         6.1
#
# [133 rows x 2 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_inflation_rate_daily=df_au_inflation_rate.resample('D').ffill()
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-09-02          8.0         NaN
# 1989-09-03          8.0         NaN
# 1989-09-04          8.0         NaN
# 1989-09-05          8.0         NaN
# ...                 ...         ...
# 2022-12-17          1.9         1.7
# 2022-12-18          1.8         1.8
# 2022-12-19          1.8         1.5
# 2022-12-20          0.9         1.2
# 2022-12-21          3.5         2.6
#
# [12165 rows x 2 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_au_inflation_rate_daily = df_au_inflation_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 2012-12-01          5.8         NaN
# 2012-12-02          5.8         NaN
# 2012-12-03          5.8         NaN
# 2012-12-04          5.8         NaN
# 2012-12-05          5.8         NaN
# ...                 ...         ...
# 2022-11-26          7.3         6.1
# 2022-11-27          7.3         6.1
# 2022-11-28          7.3         6.1
# 2022-11-29          7.3         6.1
# 2022-11-30          7.3         6.1
#
# [3652 rows x 2 columns]

# %%
df_au_inflation_rate_daily = df_au_inflation_rate_daily.drop(columns = ["Unnamed: 2"])
df_au_inflation_rate_daily
# Out:
#             Inflation %
# Date
# 2012-12-01          5.8
# 2012-12-02          5.8
# 2012-12-03          5.8
# 2012-12-04          5.8
# 2012-12-05          5.8
# ...                 ...
# 2022-11-26          7.3
# 2022-11-27          7.3
# 2022-11-28          7.3
# 2022-11-29          7.3
# 2022-11-30          7.3
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_inflation_rate_daily.columns=['au_inflation_rate']
df_au_inflation_rate_daily.head(120)
# Out:
#             au_inflation_rate
# Date
# 2012-12-01                5.8
# 2012-12-02                5.8
# 2012-12-03                5.8
# 2012-12-04                5.8
# 2012-12-05                5.8
# ...                       ...
# 2013-03-26                5.8
# 2013-03-27                5.8
# 2013-03-28                5.8
# 2013-03-29                5.8
# 2013-03-30                5.8
#
# [120 rows x 1 columns]

# %%
# Reading AU cash rate from AU_Cashrate.csv
df_au_cash_rate = pd.read_csv("./Resources/AU_Cashrate.csv",
                              index_col ="Date",
                              infer_datetime_format=True, 
                              parse_dates = True)
df_au_cash_rate
# Out:
#             Cash Rate Target on date
# Date
# 2011-01-04                      4.75
# 2011-01-05                      4.75
# 2011-01-06                      4.75
# 2011-01-07                      4.75
# 2011-01-10                      4.75
# ...                              ...
# 2022-12-22                      3.10
# 2022-12-23                      3.10
# 2022-12-28                      3.10
# 2022-12-29                      3.10
# 2022-12-30                       NaN
#
# [3036 rows x 1 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_cash_rate_daily=df_au_cash_rate.resample('D').ffill()

# %%
# selected data range from 2012-12-01 to 2022-11-30
df_au_cash_rate_daily = df_au_cash_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_cash_rate_daily
# Out:
#             Cash Rate Target on date
# Date
# 2012-12-01                      3.25
# 2012-12-02                      3.25
# 2012-12-03                      3.25
# 2012-12-04                      3.25
# 2012-12-05                      3.00
# ...                              ...
# 2022-11-26                      2.85
# 2022-11-27                      2.85
# 2022-11-28                      2.85
# 2022-11-29                      2.85
# 2022-11-30                      2.85
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_cash_rate_daily.columns=['au_cash_rate']
df_au_cash_rate_daily.head(120)
# Out:
#             au_cash_rate
# Date
# 2012-12-01          3.25
# 2012-12-02          3.25
# 2012-12-03          3.25
# 2012-12-04          3.25
# 2012-12-05          3.00
# ...                  ...
# 2013-03-26          3.00
# 2013-03-27          3.00
# 2013-03-28          3.00
# 2013-03-29          3.00
# 2013-03-30          3.00
#
# [120 rows x 1 columns]

# %%
# Concatenating all the data into one dataframe
all_df_daily = pd.concat([close_daily, new_df3_us_daily, new_data_au_daily, new_df3_us_daily_inflation, df_au_inflation_rate_daily, df_us_fed_rate_daily, df_au_cash_rate_daily,df_us_index_data], axis="columns", join="inner")
all_df_daily
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-03  1.04220                   7.9                   5.4
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-03                1.7                5.8         0.16          3.25
# 2012-12-04                1.7                5.8         0.17          3.25
# 2012-12-05                1.7                5.8         0.16          3.00
# 2012-12-06                1.7                5.8         0.16          3.00
# 2012-12-07                1.7                5.8         0.16          3.00
# ...                       ...                ...          ...           ...
# 2022-11-23                7.7                7.3         3.83          2.85
# 2022-11-24                7.7                7.3         3.83          2.85
# 2022-11-25                7.7                7.3         3.83          2.85
# 2022-11-28                7.7                7.3         3.83          2.85
# 2022-11-29                7.7                7.3         3.83          2.85
#
#             us_index_daily_data
# 2012-12-03            79.879997
# 2012-12-04            79.639999
# 2012-12-05            79.769997
# 2012-12-06            80.260002
# 2012-12-07            80.419998
# ...                         ...
# 2022-11-23           106.080002
# 2022-11-24           105.849998
# 2022-11-25           105.959999
# 2022-11-28           106.680000
# 2022-11-29           106.820000
#
# [2519 rows x 8 columns]

# %%
all_df_daily_diff = all_df_daily

all_df_daily_diff['inflation_diff']=all_df_daily['us_inflation_rate']-all_df_daily['au_inflation_rate']
all_df_daily_diff['unemployment_diff']=all_df_daily['us_unemployment_rate']-all_df_daily['au_unemployment_rate']
all_df_daily_diff['cash_rate_diff']=all_df_daily['us_fed_rate']-all_df_daily['au_cash_rate']
all_df_daily_diff
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-03  1.04220                   7.9                   5.4
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-03                1.7                5.8         0.16          3.25
# 2012-12-04                1.7                5.8         0.17          3.25
# 2012-12-05                1.7                5.8         0.16          3.00
# 2012-12-06                1.7                5.8         0.16          3.00
# 2012-12-07                1.7                5.8         0.16          3.00
# ...                       ...                ...          ...           ...
# 2022-11-23                7.7                7.3         3.83          2.85
# 2022-11-24                7.7                7.3         3.83          2.85
# 2022-11-25                7.7                7.3         3.83          2.85
# 2022-11-28                7.7                7.3         3.83          2.85
# 2022-11-29                7.7                7.3         3.83          2.85
#
#             us_index_daily_data  inflation_diff  unemployment_diff  \
# 2012-12-03            79.879997            -4.1                2.5
# 2012-12-04            79.639999            -4.1                2.5
# 2012-12-05            79.769997            -4.1                2.5
# 2012-12-06            80.260002            -4.1                2.5
# 2012-12-07            80.419998            -4.1                2.5
# ...                         ...             ...                ...
# 2022-11-23           106.080002             0.4                0.3
# 2022-11-24           105.849998             0.4                0.3
# 2022-11-25           105.959999             0.4                0.3
# 2022-11-28           106.680000             0.4                0.3
# 2022-11-29           106.820000             0.4                0.3
#
#             cash_rate_diff
# 2012-12-03           -3.09
# 2012-12-04           -3.08
# 2012-12-05           -2.84
# 2012-12-06           -2.84
# 2012-12-07           -2.84
# ...                    ...
# 2022-11-23            0.98
# 2022-11-24            0.98
# 2022-11-25            0.98
# 2022-11-28            0.98
# 2022-11-29            0.98
#
# [2519 rows x 11 columns]

# %%
all_df_daily_diff=all_df_daily_diff.drop(columns=['us_unemployment_rate','au_unemployment_rate','us_inflation_rate','au_inflation_rate','us_fed_rate','au_cash_rate'])

all_df_daily_diff
# Out:
#               close  us_index_daily_data  inflation_diff  unemployment_diff  \
# 2012-12-03  1.04220            79.879997            -4.1                2.5
# 2012-12-04  1.04710            79.639999            -4.1                2.5
# 2012-12-05  1.04560            79.769997            -4.1                2.5
# 2012-12-06  1.04870            80.260002            -4.1                2.5
# 2012-12-07  1.04890            80.419998            -4.1                2.5
# ...             ...                  ...             ...                ...
# 2022-11-23  0.67351           106.080002             0.4                0.3
# 2022-11-24  0.67646           105.849998             0.4                0.3
# 2022-11-25  0.67524           105.959999             0.4                0.3
# 2022-11-28  0.66524           106.680000             0.4                0.3
# 2022-11-29  0.66879           106.820000             0.4                0.3
#
#             cash_rate_diff
# 2012-12-03           -3.09
# 2012-12-04           -3.08
# 2012-12-05           -2.84
# 2012-12-06           -2.84
# 2012-12-07           -2.84
# ...                    ...
# 2022-11-23            0.98
# 2022-11-24            0.98
# 2022-11-25            0.98
# 2022-11-28            0.98
# 2022-11-29            0.98
#
# [2519 rows x 5 columns]

# %%
#all_df_daily['au/us unemployment ratio']=all_df_daily['au_unemployment_rate']/all_df_daily['us_unemployment_rate']

# %%
#all_df_daily['au/us inflation ratio']=all_df_daily['au_inflation_rate']/all_df_daily['us_inflation_rate']

# %%
#all_df_daily['au/us interest ratio']=all_df_daily['au_cash_rate']/all_df_daily['us_fed_rate']

# %%
#all_df_daily

# %%
#ml_ready_df = all_df_daily.copy().drop(columns=["us_unemployment_rate", "au_unemployment_rate", "us_inflation_rate", "au_inflation_rate", "us_fed_rate", "au_cash_rate"])
#ml_ready_df

# %% [markdown]
# ### Create the labels set (`y`)  from the “close” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# # Separate the data into labels and features

# # Separate the y variable, the labels
# y = all_df_daily['close']

# # Separate the X variable, the features
# X = all_df_daily.copy().drop(columns = 'close')

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = all_df_daily_diff['close']

# Separate the X variable, the features
X = all_df_daily_diff.copy().drop(columns = 'close')

# %%
# Review the y variable Series
y[0:5]
# Out:
# 2012-12-03    1.0422
# 2012-12-04    1.0471
# 2012-12-05    1.0456
# 2012-12-06    1.0487
# 2012-12-07    1.0489
# Name: close, dtype: float64

# %%
# Review the X variable DataFrame
X
# Out:
#             us_unemployment_rate  au_unemployment_rate  us_inflation_rate  \
# 2012-12-03                   7.9                   5.4                1.7
# 2012-12-04                   7.9                   5.4                1.7
# 2012-12-05                   7.9                   5.4                1.7
# 2012-12-06                   7.9                   5.4                1.7
# 2012-12-07                   7.9                   5.4                1.7
# ...                          ...                   ...                ...
# 2022-11-23                   3.7                   3.4                7.7
# 2022-11-24                   3.7                   3.4                7.7
# 2022-11-25                   3.7                   3.4                7.7
# 2022-11-28                   3.7                   3.4                7.7
# 2022-11-29                   3.7                   3.4                7.7
#
#             au_inflation_rate  us_fed_rate  au_cash_rate  us_index_daily_data  \
# 2012-12-03                5.8         0.16          3.25            79.879997
# 2012-12-04                5.8         0.17          3.25            79.639999
# 2012-12-05                5.8         0.16          3.00            79.769997
# 2012-12-06                5.8         0.16          3.00            80.260002
# 2012-12-07                5.8         0.16          3.00            80.419998
# ...                       ...          ...           ...                  ...
# 2022-11-23                7.3         3.83          2.85           106.080002
# 2022-11-24                7.3         3.83          2.85           105.849998
# 2022-11-25                7.3         3.83          2.85           105.959999
# 2022-11-28                7.3         3.83          2.85           106.680000
# 2022-11-29                7.3         3.83          2.85           106.820000
#
#             inflation_diff  unemployment_diff  cash_rate_diff
# 2012-12-03            -4.1                2.5           -3.09
# 2012-12-04            -4.1                2.5           -3.08
# 2012-12-05            -4.1                2.5           -2.84
# 2012-12-06            -4.1                2.5           -2.84
# 2012-12-07            -4.1                2.5           -2.84
# ...                    ...                ...             ...
# 2022-11-23             0.4                0.3            0.98
# 2022-11-24             0.4                0.3            0.98
# 2022-11-25             0.4                0.3            0.98
# 2022-11-28             0.4                0.3            0.98
# 2022-11-29             0.4                0.3            0.98
#
# [2519 rows x 10 columns]

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)

# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(years=8)

# Display the training end date
print(training_end)


# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train
# Out:
# 2012-12-03 00:00:00
# 2020-12-03 00:00:00
#             us_unemployment_rate  au_unemployment_rate  us_inflation_rate  \
# 2012-12-03                   7.9                   5.4                1.7
# 2012-12-04                   7.9                   5.4                1.7
# 2012-12-05                   7.9                   5.4                1.7
# 2012-12-06                   7.9                   5.4                1.7
# 2012-12-07                   7.9                   5.4                1.7
# ...                          ...                   ...                ...
# 2020-11-27                   6.7                   6.8                1.2
# 2020-11-30                   6.7                   6.8                1.2
# 2020-12-01                   6.7                   6.6                1.4
# 2020-12-02                   6.7                   6.6                1.4
# 2020-12-03                   6.7                   6.6                1.4
#
#             au_inflation_rate  us_fed_rate  au_cash_rate  us_index_daily_data  \
# 2012-12-03                5.8         0.16          3.25            79.879997
# 2012-12-04                5.8         0.17          3.25            79.639999
# 2012-12-05                5.8         0.16          3.00            79.769997
# 2012-12-06                5.8         0.16          3.00            80.260002
# 2012-12-07                5.8         0.16          3.00            80.419998
# ...                       ...          ...           ...                  ...
# 2020-11-27                5.8         0.08          0.10            91.790001
# 2020-11-30                5.8         0.09          0.10            91.870003
# 2020-12-01                5.8         0.09          0.10            91.309998
# 2020-12-02                5.8         0.09          0.10            91.120003
# 2020-12-03                5.8         0.09          0.10            90.709999
#
#             inflation_diff  unemployment_diff  cash_rate_diff
# 2012-12-03            -4.1                2.5           -3.09
# 2012-12-04            -4.1                2.5           -3.08
# 2012-12-05            -4.1                2.5           -2.84
# 2012-12-06            -4.1                2.5           -2.84
# 2012-12-07            -4.1                2.5           -2.84
# ...                    ...                ...             ...
# 2020-11-27            -4.6               -0.1           -0.02
# 2020-11-30            -4.6               -0.1           -0.01
# 2020-12-01            -4.4                0.1           -0.01
# 2020-12-02            -4.4                0.1           -0.01
# 2020-12-03            -4.4                0.1           -0.01
#
# [2015 rows x 10 columns]

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(days=1):]
y_test = y.loc[training_end+DateOffset(days=1):]


# Review the X_test DataFrame
X_test
# Out:
#             us_unemployment_rate  au_unemployment_rate  us_inflation_rate  \
# 2020-12-04                   6.7                   6.6                1.4
# 2020-12-07                   6.7                   6.6                1.4
# 2020-12-08                   6.7                   6.6                1.4
# 2020-12-09                   6.7                   6.6                1.4
# 2020-12-10                   6.7                   6.6                1.4
# ...                          ...                   ...                ...
# 2022-11-23                   3.7                   3.4                7.7
# 2022-11-24                   3.7                   3.4                7.7
# 2022-11-25                   3.7                   3.4                7.7
# 2022-11-28                   3.7                   3.4                7.7
# 2022-11-29                   3.7                   3.4                7.7
#
#             au_inflation_rate  us_fed_rate  au_cash_rate  us_index_daily_data  \
# 2020-12-04                5.8         0.09          0.10            90.699997
# 2020-12-07                5.8         0.09          0.10            90.790001
# 2020-12-08                5.8         0.09          0.10            90.970001
# 2020-12-09                5.8         0.09          0.10            91.089996
# 2020-12-10                5.8         0.09          0.10            90.790001
# ...                       ...          ...           ...                  ...
# 2022-11-23                7.3         3.83          2.85           106.080002
# 2022-11-24                7.3         3.83          2.85           105.849998
# 2022-11-25                7.3         3.83          2.85           105.959999
# 2022-11-28                7.3         3.83          2.85           106.680000
# 2022-11-29                7.3         3.83          2.85           106.820000
#
#             inflation_diff  unemployment_diff  cash_rate_diff
# 2020-12-04            -4.4                0.1           -0.01
# 2020-12-07            -4.4                0.1           -0.01
# 2020-12-08            -4.4                0.1           -0.01
# 2020-12-09            -4.4                0.1           -0.01
# 2020-12-10            -4.4                0.1           -0.01
# ...                    ...                ...             ...
# 2022-11-23             0.4                0.3            0.98
# 2022-11-24             0.4                0.3            0.98
# 2022-11-25             0.4                0.3            0.98
# 2022-11-28             0.4                0.3            0.98
# 2022-11-29             0.4                0.3            0.98
#
# [504 rows x 10 columns]

# %%
y_test
# Out:
# 2020-12-04    0.74267
# 2020-12-07    0.74212
# 2020-12-08    0.74098
# 2020-12-09    0.74433
# 2020-12-10    0.75354
#                ...
# 2022-11-23    0.67351
# 2022-11-24    0.67646
# 2022-11-25    0.67524
# 2022-11-28    0.66524
# 2022-11-29    0.66879
# Name: close, Length: 504, dtype: float64

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
X_scaler = scaler.fit(X_train)

# %%
# Transform the X_train and X_test DataFrames using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# creating a regression model
model = LinearRegression()

# %%
# fitting the model
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# making predictions
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([0.70467103, 0.7040615 , 0.7028425 , 0.70202986, 0.7040615 ,
#        0.70277476, 0.7046033 , 0.70622862, 0.70636409, 0.71063059,
#        0.70927616, 0.70914069, 0.70500961, 0.70663494, 0.70717673,
#        0.70710905, 0.70934385, 0.71191734, 0.70981791, 0.70903976,
#        0.71201951, 0.71141003, 0.70937834, 0.70754986, 0.70457005,
#        0.70788844, 0.70605995, 0.70660174, 0.70294472, 0.70484095,
#        0.70504411, 0.7075176 , 0.70677264, 0.7057568 , 0.7072467 ,
#        0.703996  , 0.70545364, 0.70464095, 0.71210896, 0.71088996,
#        0.7114317 , 0.7086551 , 0.71197349, 0.71288934, 0.71603683,
#        0.71651088, 0.7161723 , 0.71576593, 0.71556277, 0.71258302,
#        0.71519193, 0.71674952, 0.71911979, 0.71803626, 0.71796853,
#        0.71830716, 0.71288934, 0.73674217, 0.73843523, 0.7373517 ,
#        0.73274658, 0.73037625, 0.72814144, 0.73051172, 0.73166299,
#        0.73416874, 0.73240794, 0.73139209, 0.7311212 , 0.73430416,
#        0.73125668, 0.73078262, 0.73159525, 0.72793829, 0.72665154,
#        0.72428127, 0.72502622, 0.7238749 , 0.72143689, 0.72208184,
#        0.76961597, 0.77185083, 0.77361163, 0.77279894, 0.77550784,
#        0.77483058, 0.77496605, 0.77693001, 0.77801354, 0.77814902,
#        0.77889396, 0.78221235, 0.78106108, 0.78160282, 0.78045155,
#        0.78363451, 0.78397315, 0.78329588, 0.78532758, 0.78549848,
#        0.78113199, 0.80568481, 0.80338222, 0.80324679, 0.80568481,
#        0.81056079, 0.81069626, 0.81117031, 0.80731013, 0.80703924,
#        0.8099513 , 0.81062852, 0.81381148, 0.81083168, 0.81340516,
#        0.811983  , 0.81326969, 0.81455644, 0.81184753, 0.81232158,
#        0.81208616, 0.82585615, 0.82538209, 0.82131876, 0.82375677,
#        0.82504351, 0.82416309, 0.82389219, 0.82416309, 0.82091244,
#        0.82118333, 0.82104786, 0.81705226, 0.81122174, 0.80891915,
#        0.8114249 , 0.81230527, 0.81183122, 0.81169579, 0.81176353,
#        0.81128948, 0.81013816, 0.80783879, 0.80421832, 0.80672402,
#        0.8045569 , 0.80394743, 0.80584364, 0.80740129, 0.80672402,
#        0.80320247, 0.80550501, 0.80408284, 0.80360879, 0.80225437,
#        0.80171257, 0.80320247, 0.80272842, 0.80211889, 0.80387968,
#        0.80536959, 0.80611454, 0.80922976, 0.80764309, 0.80416068,
#        0.80395752, 0.80267082, 0.80287398, 0.79908149, 0.7980657 ,
#        0.79732074, 0.79833654, 0.79745617, 0.80097776, 0.80023282,
#        0.79684669, 0.79694986, 0.79403779, 0.79451184, 0.79816886,
#        0.79864292, 0.79904923, 0.79749164, 0.80016825, 0.80043914,
#        0.80091642, 0.79971896, 0.80120881, 0.80249555, 0.7992449 ,
#        0.79836447, 0.79951575, 0.79883853, 0.79856763, 0.79836447,
#        0.79944806, 0.79694231, 0.79463977, 0.79436887, 0.79463977,
#        0.79287897, 0.79531699, 0.79375935, 0.79342077, 0.79077959,
#        0.78691942, 0.7878707 , 0.80697411, 0.80853175, 0.80738043,
#        0.80541652, 0.80575511, 0.80677095, 0.80507789, 0.80372346,
#        0.80670322, 0.80751591, 0.80765133, 0.80758364, 0.80866717,
#        0.81022481, 0.80880265, 0.80988618, 0.80853175, 0.80758364,
#        0.80819312, 0.81164698, 0.80660322, 0.82531812, 0.82389596,
#        0.82545354, 0.82213516, 0.82233831, 0.8241668 , 0.82477633,
#        0.81874904, 0.81651418, 0.81685282, 0.81495654, 0.81150274,
#        0.81211221, 0.81407617, 0.81048689, 0.80757482, 0.80764256,
#        0.80527228, 0.81035147, 0.80865841, 0.81119958, 0.81630689,
#        0.81576515, 0.81583283, 0.81468156, 0.81413977, 0.81739048,
#        0.81481704, 0.81630689, 0.8144784 , 0.81278534, 0.81319166,
#        0.81637463, 0.81278534, 0.81292077, 0.81332714, 0.81610373,
#        0.8165101 , 0.81603605, 0.81529109, 0.81711958, 0.81684868,
#        0.81905128, 0.82971557, 0.82937694, 0.83005416, 0.82964784,
#        0.83310169, 0.83140863, 0.83391433, 0.83811314, 0.83953531,
#        0.83696187, 0.83316938, 0.83465928, 0.83310169, 0.83377891,
#        0.83188269, 0.83167953, 0.82802251, 0.82280785, 0.82274017,
#        0.82768388, 0.83943885, 0.84248634, 0.84627884, 0.84560157,
#        0.84614336, 0.84451804, 0.84553388, 0.84512751, 0.84153823,
#        0.83957427, 0.84214776, 0.84411172, 0.84343445, 0.84180913,
#        0.84187686, 0.84079328, 0.83435967, 0.83788121, 0.83727174,
#        0.84537917, 0.88709062, 0.88022411, 0.89241623, 0.88115267,
#        0.85776473, 0.8914779 , 0.88089155, 0.87121702, 0.87716685,
#        0.89927296, 0.90394583, 0.89109209, 0.89237392, 0.90163236,
#        0.84626546, 0.84538504, 0.84423377, 0.84409834, 0.84220213,
#        0.84687494, 0.85100601, 0.84748447, 0.83977389, 0.83733588,
#        0.83408518, 0.83320481, 0.83218896, 0.83185032, 0.83096995,
#        0.82853194, 0.83130859, 0.82832878, 0.82521355, 0.82399455,
#        0.82785473, 0.82656798, 0.82223375, 0.81864447, 0.81491971,
#        0.81051779, 0.80598035, 0.81045006, 0.81348291, 0.81531139,
#        0.83764665, 0.82124578, 0.82185526, 0.82192299, 0.82009451,
#        0.82056857, 0.81379633, 0.81576028, 0.81826598, 0.82388695,
#        0.82083946, 0.82822119, 0.82530912, 0.83255542, 0.83404532,
#        0.83269089, 0.83424848, 0.83533207, 0.83736371, 0.83479027,
#        0.83136091, 0.88237687, 0.88264285, 0.86120904, 0.88835317,
#        0.88773965, 0.9247105 , 0.89485259, 0.89825546, 0.88696051,
#        0.91018646, 0.91465982, 0.89494072, 0.92691962, 0.87037002,
#        0.84012048, 0.83856285, 0.84018817, 0.84188123, 0.83802105,
#        0.83395771, 0.83680205, 0.81695027, 0.81661164, 0.80774001,
#        0.83642797, 0.83622481, 0.83703744, 0.83019751, 0.82985888,
#        0.83060383, 0.82667592, 0.82992661, 0.83459943, 0.8392723 ,
#        0.83656339, 0.83771465, 0.83893367, 0.84062673, 0.83581844,
#        0.84082994, 0.8286896 , 0.83190798, 0.8309146 , 0.82556452,
#        0.85648728, 0.86204052, 0.85574232, 0.85696133, 0.85743538,
#        0.86535895, 0.8661039 , 0.86244688, 0.85621638, 0.85655501,
#        0.85608095, 0.84991819, 0.84524538, 0.83928577, 0.84219783,
#        0.84179152, 0.84321368, 0.84097883, 0.84070799, 0.84118204,
#        0.84165609, 0.87973472, 0.87111724, 0.85542519, 0.92117128,
#        0.87770395, 0.93517513, 0.9286256 , 0.91576324, 0.9154609 ,
#        0.92600609, 0.92864235, 0.92323436, 0.93384232, 0.89912308,
#        0.82190501, 0.80944405, 0.80328133, 0.80321359, 0.8134397 ,
#        0.81580997, 0.81669035, 0.8083365 , 0.81971388, 0.82931728,
#        0.82125829, 0.81760127, 0.81529874, 0.81475694, 0.81407973,
#        0.82058107, 0.81414746, 0.82274819, 0.82213872, 0.81638227,
#        0.81705953, 0.82295135, 0.82308682, 0.83012997, 0.83859527,
#        0.83256798, 0.83202619, 0.82620205, 0.82654064, 0.84379671,
#        0.82027899, 0.83416212, 0.83930898, 0.8426951 , 0.83639692,
#        0.852244  , 0.86524669, 0.86274094, 0.86450174, 0.86531443,
#        0.86253779, 0.86091246, 0.85474975, 0.85894851, 0.86666886,
#        0.8682265 , 0.86748155, 0.86260553, 0.86165741])

# %%
df_predictions = pd.DataFrame(predictions)
df_predictions
# Out:
#             0
# 0    0.704671
# 1    0.704062
# 2    0.702842
# 3    0.702030
# 4    0.704062
# ..        ...
# 499  0.866669
# 500  0.868227
# 501  0.867482
# 502  0.862606
# 503  0.861657
#
# [504 rows x 1 columns]

# %%
df_predictions.index=y_test.index
df_predictions
# Out:
#                    0
# 2020-12-04  0.704671
# 2020-12-07  0.704062
# 2020-12-08  0.702842
# 2020-12-09  0.702030
# 2020-12-10  0.704062
# ...              ...
# 2022-11-23  0.866669
# 2022-11-24  0.868227
# 2022-11-25  0.867482
# 2022-11-28  0.862606
# 2022-11-29  0.861657
#
# [504 rows x 1 columns]

# %%
print(f"R-squared of training data is: {model.score(X_train_scaled, y_train)}")
print(f"R-squared of testing data is: {model.score(X_test_scaled, y_test)}")
# Out:
# R-squared of training data is: 0.9238664626744171
# R-squared of testing data is: -7.890691866014587

# %%
y_test
# Out:
# 2020-12-04    0.74267
# 2020-12-07    0.74212
# 2020-12-08    0.74098
# 2020-12-09    0.74433
# 2020-12-10    0.75354
#                ...
# 2022-11-23    0.67351
# 2022-11-24    0.67646
# 2022-11-25    0.67524
# 2022-11-28    0.66524
# 2022-11-29    0.66879
# Name: close, Length: 504, dtype: float64

# %%
df_y_test=y_test.to_frame()

df_y_test
# Out:
#               close
# 2020-12-04  0.74267
# 2020-12-07  0.74212
# 2020-12-08  0.74098
# 2020-12-09  0.74433
# 2020-12-10  0.75354
# ...             ...
# 2022-11-23  0.67351
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
#
# [504 rows x 1 columns]

# %%
# Create a new empty predictions DataFrame.

predictions_df=pd.DataFrame({})

# Create a predictions DataFrame
predictions_df.index=df_y_test.index

predictions_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-12-04 00:00:00, 2020-12-07 00:00:00, 2020-12-08 00:00:00, 2020-12-09 00:00:00, 2020-12-10 00:00:00, 2020-12-11 00:00:00, 2020-12-14 00:00:00, 2020-12-15 00:00:00, 2020-12-16 00:00:00, 2020-12-17 00:00:00, 2020-12-18 00:00:00, 2020-12-21 00:00:00, 2020-12-22 00:00:00, 2020-12-23 00:00:00, 2020-12-24 00:00:00, 2020-12-28 00:00:00, 2020-12-29 00:00:00, 2020-12-30 00:00:00, 2020-12-31 00:00:00, 2021-01-04 00:00:00, 2021-01-05 00:00:00, 2021-01-06 00:00:00, 2021-01-07 00:00:00, 2021-01-08 00:00:00, 2021-01-11 00:00:00, 2021-01-12 00:00:00, 2021-01-13 00:00:00, 2021-01-14 00:00:00, 2021-01-15 00:00:00, 2021-01-19 00:00:00, 2021-01-20 00:00:00, 2021-01-21 00:00:00, 2021-01-22 00:00:00, 2021-01-25 00:00:00, 2021-01-26 00:00:00, 2021-01-27 00:00:00, 2021-01-28 00:00:00, 2021-01-29 00:00:00, 2021-02-01 00:00:00, 2021-02-02 00:00:00, 2021-02-03 00:00:00, 2021-02-04 00:00:00, 2021-02-05 00:00:00, 2021-02-08 00:00:00, 2021-02-09 00:00:00, 2021-02-10 00:00:00, 2021-02-11 00:00:00, 2021-02-12 00:00:00, 2021-02-16 00:00:00, 2021-02-17 00:00:00, 2021-02-18 00:00:00, 2021-02-19 00:00:00, 2021-02-22 00:00:00, 2021-02-23 00:00:00, 2021-02-24 00:00:00, 2021-02-25 00:00:00, 2021-02-26 00:00:00, 2021-03-01 00:00:00, 2021-03-02 00:00:00, 2021-03-03 00:00:00, 2021-03-04 00:00:00, 2021-03-05 00:00:00, 2021-03-08 00:00:00, 2021-03-09 00:00:00, 2021-03-10 00:00:00, 2021-03-11 00:00:00, 2021-03-12 00:00:00, 2021-03-15 00:00:00, 2021-03-16 00:00:00, 2021-03-17 00:00:00, 2021-03-18 00:00:00, 2021-03-19 00:00:00, 2021-03-22 00:00:00, 2021-03-23 00:00:00, 2021-03-24 00:00:00, 2021-03-25 00:00:00, 2021-03-26 00:00:00, 2021-03-29 00:00:00, 2021-03-30 00:00:00, 2021-03-31 00:00:00, 2021-04-01 00:00:00, 2021-04-05 00:00:00, 2021-04-06 00:00:00, 2021-04-07 00:00:00, 2021-04-08 00:00:00, 2021-04-09 00:00:00, 2021-04-12 00:00:00, 2021-04-13 00:00:00, 2021-04-14 00:00:00, 2021-04-15 00:00:00, 2021-04-16 00:00:00, 2021-04-19 00:00:00, 2021-04-20 00:00:00, 2021-04-21 00:00:00, 2021-04-22 00:00:00, 2021-04-23 00:00:00, 2021-04-26 00:00:00, 2021-04-27 00:00:00, 2021-04-28 00:00:00, 2021-04-29 00:00:00, ...]
#
# [504 rows x 0 columns]

# %%
predictions_df['predictions']=df_predictions

predictions_df
# Out:
#             predictions
# 2020-12-04     0.704671
# 2020-12-07     0.704062
# 2020-12-08     0.702842
# 2020-12-09     0.702030
# 2020-12-10     0.704062
# ...                 ...
# 2022-11-23     0.866669
# 2022-11-24     0.868227
# 2022-11-25     0.867482
# 2022-11-28     0.862606
# 2022-11-29     0.861657
#
# [504 rows x 1 columns]

# %%
predictions_df['actuals']=df_y_test['close']

predictions_df
# Out:
#             predictions  actuals
# 2020-12-04     0.704671  0.74267
# 2020-12-07     0.704062  0.74212
# 2020-12-08     0.702842  0.74098
# 2020-12-09     0.702030  0.74433
# 2020-12-10     0.704062  0.75354
# ...                 ...      ...
# 2022-11-23     0.866669  0.67351
# 2022-11-24     0.868227  0.67646
# 2022-11-25     0.867482  0.67524
# 2022-11-28     0.862606  0.66524
# 2022-11-29     0.861657  0.66879
#
# [504 rows x 2 columns]

# %%
predictions_df.plot()
# Out:
# <AxesSubplot:>
