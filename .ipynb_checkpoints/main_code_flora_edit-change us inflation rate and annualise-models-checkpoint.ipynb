# %%
from dotenv import load_dotenv
import os
import tradermade as tm
import pandas as pd
from pathlib import Path
import datetime as dt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler
from pandas.tseries.offsets import DateOffset

import warnings
warnings.filterwarnings('ignore')

# %%
pip install tradermade
# Out:
# Requirement already satisfied: tradermade in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (0.5.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (1.3.5)
# Requirement already satisfied: requests>=2.25.1 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (2.28.1)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (1.21.6)
# Requirement already satisfied: websockets==8.1 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from tradermade) (8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from pandas>=0.24.2->tradermade) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from pandas>=0.24.2->tradermade) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from requests>=2.25.1->tradermade) (1.26.13)
# Requirement already satisfied: six>=1.5 in c:\users\xuxuz\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tradermade) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# # Set environment variables from the .env in the local environment
# load_dotenv()

# %%
# # Retrieve API key and store as Python variable
# api_key = os.getenv("TRADERMADE_API_KEY")
# type(api_key)

# %%
# # set api key
# tm.set_rest_api_key(api_key)

# %% [markdown]
# # Gain Forex close price time series data from API

# %%
# # get timeseries data
# import pandas as pd
# df = pd.DataFrame()
# for i in range(2012, 2022):  
#     x = tm.timeseries(currency='AUDUSD', start=str(i)+"-12-01",fields=["open", "high", "low","close"], end=str(i+1)+"-11-30")
#     df = df.append(x)
# df = df.drop_duplicates()
# df
# # returns timeseries data for the currency requested interval is daily, hourly, minute - fields parameter is optional (you can select ["close"] if you just want close prices)

# %%
# df.index = pd.to_datetime(df['date'])

# %%
# df = df.drop(columns = "date")
# df

# %%
# close_daily = df.drop(columns=["open", "high", "low"])

# %%
# close_daily

# %%
# close_daily_reset_index.to_csv('close_daily_reset_index.csv', encoding='utf-8', index=True)

# %%
# Read in daily close price csv file into dataframe
path_close_daily = "./Resources/close_daily.csv"
close_daily = pd.read_csv(path_close_daily, parse_dates = True, infer_datetime_format = True, index_col = "date")
close_daily
# Out:
#               close
# date
# 2012-12-03  1.04220
# 2012-12-04  1.04710
# 2012-12-05  1.04560
# 2012-12-06  1.04870
# 2012-12-07  1.04890
# ...             ...
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
# 2022-11-30  0.67880
#
# [2608 rows x 1 columns]

# %% [markdown]
# # Read US unemployment rate data from csv file to a dataframe, convert the data into time series and slice the data from Dec 2012 to Nov 2022

# %%
# read us unemployment rate csv file into dataframe
path_str_us = "./Resources/US-Unemployment rate-2012 to 2022.csv"
path_us = Path(path_str_us)
data_us = pd.read_csv(path_us, parse_dates = True,infer_datetime_format = True)
data_us
# Out:
#     Year  Jan  Feb  Mar   Apr   May   Jun   Jul  Aug  Sep  Oct  Nov  Dec
# 0   2012  8.3  8.3  8.2   8.2   8.2   8.2   8.2  8.1  7.8  7.8  7.7  7.9
# 1   2013  8.0  7.7  7.5   7.6   7.5   7.5   7.3  7.2  7.2  7.2  6.9  6.7
# 2   2014  6.6  6.7  6.7   6.2   6.3   6.1   6.2  6.1  5.9  5.7  5.8  5.6
# 3   2015  5.7  5.5  5.4   5.4   5.6   5.3   5.2  5.1  5.0  5.0  5.1  5.0
# 4   2016  4.8  4.9  5.0   5.1   4.8   4.9   4.8  4.9  5.0  4.9  4.7  4.7
# 5   2017  4.7  4.6  4.4   4.4   4.4   4.3   4.3  4.4  4.3  4.2  4.2  4.1
# 6   2018  4.0  4.1  4.0   4.0   3.8   4.0   3.8  3.8  3.7  3.8  3.8  3.9
# 7   2019  4.0  3.8  3.8   3.6   3.6   3.6   3.7  3.7  3.5  3.6  3.6  3.6
# 8   2020  3.5  3.5  4.4  14.7  13.2  11.0  10.2  8.4  7.9  6.9  6.7  6.7
# 9   2021  6.4  6.2  6.0   6.0   5.8   5.9   5.4  5.2  4.7  4.6  4.2  3.9
# 10  2022  4.0  3.8  3.6   3.6   3.6   3.6   3.5  3.7  3.5  3.7  3.7  NaN

# %%
# convert to 1 dimension time series data
new_data_us=data_us.set_index('Year')
df1_us=new_data_us.stack()
df1_us
# Out:
# Year
# 2012  Jan    8.3
#       Feb    8.3
#       Mar    8.2
#       Apr    8.2
#       May    8.2
#             ...
# 2022  Jul    3.5
#       Aug    3.7
#       Sep    3.5
#       Oct    3.7
#       Nov    3.7
# Length: 131, dtype: float64

# %%
df2_us=df1_us.reset_index()
df2_us
# Out:
#      Year level_1    0
# 0    2012     Jan  8.3
# 1    2012     Feb  8.3
# 2    2012     Mar  8.2
# 3    2012     Apr  8.2
# 4    2012     May  8.2
# ..    ...     ...  ...
# 126  2022     Jul  3.5
# 127  2022     Aug  3.7
# 128  2022     Sep  3.5
# 129  2022     Oct  3.7
# 130  2022     Nov  3.7
#
# [131 rows x 3 columns]

# %%
# Rename columns' name
df2_us.columns = ['Year','Month','us_rate']
df2_us
# Out:
#      Year Month  us_rate
# 0    2012   Jan      8.3
# 1    2012   Feb      8.3
# 2    2012   Mar      8.2
# 3    2012   Apr      8.2
# 4    2012   May      8.2
# ..    ...   ...      ...
# 126  2022   Jul      3.5
# 127  2022   Aug      3.7
# 128  2022   Sep      3.5
# 129  2022   Oct      3.7
# 130  2022   Nov      3.7
#
# [131 rows x 3 columns]

# %%
# Slice the data to Dec 2012 to Nov 2022 period
df3_us= df2_us[11:]
df3_us=df3_us.reset_index()
df3_us
# Out:
#      index  Year Month  us_rate
# 0       11  2012   Dec      7.9
# 1       12  2013   Jan      8.0
# 2       13  2013   Feb      7.7
# 3       14  2013   Mar      7.5
# 4       15  2013   Apr      7.6
# ..     ...   ...   ...      ...
# 115    126  2022   Jul      3.5
# 116    127  2022   Aug      3.7
# 117    128  2022   Sep      3.5
# 118    129  2022   Oct      3.7
# 119    130  2022   Nov      3.7
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe
df3_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    120 non-null    int64
#  1   Year     120 non-null    int64
#  2   Month    120 non-null    object
#  3   us_rate  120 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
df_us=df3_us.drop(columns=['index','Year','Month'])
df_us
# Out:
#      us_rate
# 0        7.9
# 1        8.0
# 2        7.7
# 3        7.5
# 4        7.6
# ..       ...
# 115      3.5
# 116      3.7
# 117      3.5
# 118      3.7
# 119      3.7
#
# [120 rows x 1 columns]

# %% [markdown]
# # Read AU unemployment rate data from csv file to a dataframe, slice the data from Dec 2012 to Nov 2022

# %%
# Read au unemployment data from csv file to dataframe
path_str_au = "./Resources/AU-Unemployment rate-2012 to 2022.csv"
path_au = Path(path_str_au)
data_au = pd.read_csv(path_au, parse_dates = True,infer_datetime_format = True)
data_au
# Out:
#                                             Unnamed: 0  Trend (%)  \
# 0                                               Nov-12        5.4
# 1                                               Dec-12        5.4
# 2                                               Jan-13        5.4
# 3                                               Feb-13        5.5
# 4                                               Mar-13        5.6
# ..                                                 ...        ...
# 120                                             Nov-22        3.5
# 121                                                NaN        NaN
# 122  Large month-to-month changes occurred during t...        NaN
# 123                                                NaN        NaN
# 124  Source: Australian Bureau of Statistics, Labou...        NaN
#
#      Seasonally adjusted (%)
# 0                        5.3
# 1                        5.4
# 2                        5.4
# 3                        5.4
# 4                        5.6
# ..                       ...
# 120                      3.4
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
#
# [125 rows x 3 columns]

# %%
# Slice the data from Dec 2012
data_au=data_au[1:121]
data_au
# Out:
#     Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 1       Dec-12        5.4                      5.4
# 2       Jan-13        5.4                      5.4
# 3       Feb-13        5.5                      5.4
# 4       Mar-13        5.6                      5.6
# 5       Apr-13        5.6                      5.6
# ..         ...        ...                      ...
# 116     Jul-22        3.6                      3.5
# 117     Aug-22        3.5                      3.5
# 118     Sep-22        3.5                      3.6
# 119     Oct-22        3.5                      3.4
# 120     Nov-22        3.5                      3.4
#
# [120 rows x 3 columns]

# %%
# Drop null data and slice the data from Dec 2012 to Nov 2022
data_au=data_au.reset_index()
data_au
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 0        1     Dec-12        5.4                      5.4
# 1        2     Jan-13        5.4                      5.4
# 2        3     Feb-13        5.5                      5.4
# 3        4     Mar-13        5.6                      5.6
# 4        5     Apr-13        5.6                      5.6
# ..     ...        ...        ...                      ...
# 115    116     Jul-22        3.6                      3.5
# 116    117     Aug-22        3.5                      3.5
# 117    118     Sep-22        3.5                      3.6
# 118    119     Oct-22        3.5                      3.4
# 119    120     Nov-22        3.5                      3.4
#
# [120 rows x 4 columns]

# %%
# Check if there is no null data in the dataframe, since the data in trend column has null data, we will use seasonally adjusted data for the unemployment rates
data_au.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    120 non-null    int64
#  1   Unnamed: 0               120 non-null    object
#  2   Trend (%)                96 non-null     float64
#  3   Seasonally adjusted (%)  120 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
# Rename columns' name
data_au_rate=data_au.drop(columns=['index','Unnamed: 0','Trend (%)'])

data_au_rate.columns= ['au_rate']
data_au_rate
# Out:
#      au_rate
# 0        5.4
# 1        5.4
# 2        5.4
# 3        5.6
# 4        5.6
# ..       ...
# 115      3.5
# 116      3.5
# 117      3.6
# 118      3.4
# 119      3.4
#
# [120 rows x 1 columns]

# %%
us_au_unemployment_df = pd.concat([data_au_rate,df_us],axis=1)

# %%
us_au_unemployment_df
# Out:
#      au_rate  us_rate
# 0        5.4      7.9
# 1        5.4      8.0
# 2        5.4      7.7
# 3        5.6      7.5
# 4        5.6      7.6
# ..       ...      ...
# 115      3.5      3.5
# 116      3.5      3.7
# 117      3.6      3.5
# 118      3.4      3.7
# 119      3.4      3.7
#
# [120 rows x 2 columns]

# %%
#Check if the data is valid
us_au_unemployment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   au_rate  120 non-null    float64
#  1   us_rate  120 non-null    float64
# dtypes: float64(2)
# memory usage: 2.0 KB

# %%
us_au_unemployment_df['us/au unemployment ratio']=us_au_unemployment_df['us_rate']/us_au_unemployment_df['au_rate']

# %%
us_au_unemployment_df
# Out:
#      au_rate  us_rate  us/au unemployment ratio
# 0        5.4      7.9                  1.462963
# 1        5.4      8.0                  1.481481
# 2        5.4      7.7                  1.425926
# 3        5.6      7.5                  1.339286
# 4        5.6      7.6                  1.357143
# ..       ...      ...                       ...
# 115      3.5      3.5                  1.000000
# 116      3.5      3.7                  1.057143
# 117      3.6      3.5                  0.972222
# 118      3.4      3.7                  1.088235
# 119      3.4      3.7                  1.088235
#
# [120 rows x 3 columns]

# %% [markdown]
# # Change the dataframe into daily data for daily fx rate prediction

# %% [markdown]
# ## Convert US unemployment data into daily data

# %%
# Set another column for the day and refill it with the same monthly data

df3_us_daily=df3_us
df3_us_daily['Day'] = '1'


# Add another column for the date

df3_us_daily['Date'] = df3_us_daily[['Year','Month', 'Day']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")

df3_us_daily
# Out:
#      index  Year Month  us_rate Day        Date
# 0       11  2012   Dec      7.9   1  2012-Dec-1
# 1       12  2013   Jan      8.0   1  2013-Jan-1
# 2       13  2013   Feb      7.7   1  2013-Feb-1
# 3       14  2013   Mar      7.5   1  2013-Mar-1
# 4       15  2013   Apr      7.6   1  2013-Apr-1
# ..     ...   ...   ...      ...  ..         ...
# 115    126  2022   Jul      3.5   1  2022-Jul-1
# 116    127  2022   Aug      3.7   1  2022-Aug-1
# 117    128  2022   Sep      3.5   1  2022-Sep-1
# 118    129  2022   Oct      3.7   1  2022-Oct-1
# 119    130  2022   Nov      3.7   1  2022-Nov-1
#
# [120 rows x 6 columns]

# %%
# set the last datetime in order to get full 10 year data
df3_us_daily['Date'].iloc[-1]='2022-Nov-30'
df3_us_daily
# Out:
#      index  Year Month  us_rate Day         Date
# 0       11  2012   Dec      7.9   1   2012-Dec-1
# 1       12  2013   Jan      8.0   1   2013-Jan-1
# 2       13  2013   Feb      7.7   1   2013-Feb-1
# 3       14  2013   Mar      7.5   1   2013-Mar-1
# 4       15  2013   Apr      7.6   1   2013-Apr-1
# ..     ...   ...   ...      ...  ..          ...
# 115    126  2022   Jul      3.5   1   2022-Jul-1
# 116    127  2022   Aug      3.7   1   2022-Aug-1
# 117    128  2022   Sep      3.5   1   2022-Sep-1
# 118    129  2022   Oct      3.7   1   2022-Oct-1
# 119    130  2022   Nov      3.7   1  2022-Nov-30
#
# [120 rows x 6 columns]

# %%
# Check if there is no null data in the dataframe
df3_us_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    120 non-null    int64
#  1   Year     120 non-null    int64
#  2   Month    120 non-null    object
#  3   us_rate  120 non-null    float64
#  4   Day      120 non-null    object
#  5   Date     120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
# change to datetime format
df3_us_daily['Date']=pd.to_datetime(df3_us_daily['Date'])
df3_us_daily['Date']
# Out:
# 0     2012-12-01
# 1     2013-01-01
# 2     2013-02-01
# 3     2013-03-01
# 4     2013-04-01
#          ...
# 115   2022-07-01
# 116   2022-08-01
# 117   2022-09-01
# 118   2022-10-01
# 119   2022-11-30
# Name: Date, Length: 120, dtype: datetime64[ns]

# %%
# Resample and convert to daily data
new_df3_us_daily=df3_us_daily.set_index('Date').resample('D').ffill()
new_df3_us_daily
# Out:
#             index  Year Month  us_rate Day
# Date
# 2012-12-01     11  2012   Dec      7.9   1
# 2012-12-02     11  2012   Dec      7.9   1
# 2012-12-03     11  2012   Dec      7.9   1
# 2012-12-04     11  2012   Dec      7.9   1
# 2012-12-05     11  2012   Dec      7.9   1
# ...           ...   ...   ...      ...  ..
# 2022-11-26    129  2022   Oct      3.7   1
# 2022-11-27    129  2022   Oct      3.7   1
# 2022-11-28    129  2022   Oct      3.7   1
# 2022-11-29    129  2022   Oct      3.7   1
# 2022-11-30    130  2022   Nov      3.7   1
#
# [3652 rows x 5 columns]

# %%
# Drop unnecessary columns
new_df3_us_daily=new_df3_us_daily.drop(columns=['index','Year','Month','Day'])
new_df3_us_daily
# Out:
#             us_rate
# Date
# 2012-12-01      7.9
# 2012-12-02      7.9
# 2012-12-03      7.9
# 2012-12-04      7.9
# 2012-12-05      7.9
# ...             ...
# 2022-11-26      3.7
# 2022-11-27      3.7
# 2022-11-28      3.7
# 2022-11-29      3.7
# 2022-11-30      3.7
#
# [3652 rows x 1 columns]

# %%
# Rename the column
new_df3_us_daily.columns=['us_unemployment_rate']
new_df3_us_daily.head(120)
# Out:
#             us_unemployment_rate
# Date
# 2012-12-01                   7.9
# 2012-12-02                   7.9
# 2012-12-03                   7.9
# 2012-12-04                   7.9
# 2012-12-05                   7.9
# ...                          ...
# 2013-03-26                   7.5
# 2013-03-27                   7.5
# 2013-03-28                   7.5
# 2013-03-29                   7.5
# 2013-03-30                   7.5
#
# [120 rows x 1 columns]

# %% [markdown]
# ## Convert AU unemployment data into daily data

# %%
data_au
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%)
# 0        1     Dec-12        5.4                      5.4
# 1        2     Jan-13        5.4                      5.4
# 2        3     Feb-13        5.5                      5.4
# 3        4     Mar-13        5.6                      5.6
# 4        5     Apr-13        5.6                      5.6
# ..     ...        ...        ...                      ...
# 115    116     Jul-22        3.6                      3.5
# 116    117     Aug-22        3.5                      3.5
# 117    118     Sep-22        3.5                      3.6
# 118    119     Oct-22        3.5                      3.4
# 119    120     Nov-22        3.5                      3.4
#
# [120 rows x 4 columns]

# %%
# Set another column for the day and refill it with the same monthly data

data_au_daily=data_au
data_au_daily['Day'] = '1'


# Add another column for the date

data_au_daily['Date'] = data_au_daily[['Day','Unnamed: 0']].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")

data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day      Date
# 0        1     Dec-12        5.4                      5.4   1  1-Dec-12
# 1        2     Jan-13        5.4                      5.4   1  1-Jan-13
# 2        3     Feb-13        5.5                      5.4   1  1-Feb-13
# 3        4     Mar-13        5.6                      5.6   1  1-Mar-13
# 4        5     Apr-13        5.6                      5.6   1  1-Apr-13
# ..     ...        ...        ...                      ...  ..       ...
# 115    116     Jul-22        3.6                      3.5   1  1-Jul-22
# 116    117     Aug-22        3.5                      3.5   1  1-Aug-22
# 117    118     Sep-22        3.5                      3.6   1  1-Sep-22
# 118    119     Oct-22        3.5                      3.4   1  1-Oct-22
# 119    120     Nov-22        3.5                      3.4   1  1-Nov-22
#
# [120 rows x 6 columns]

# %%
# set the last date in order to get the full 10 year period of data
data_au_daily['Date'].iloc[-1]='30-Nov-22'
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1   1-Dec-12
# 1        2     Jan-13        5.4                      5.4   1   1-Jan-13
# 2        3     Feb-13        5.5                      5.4   1   1-Feb-13
# 3        4     Mar-13        5.6                      5.6   1   1-Mar-13
# 4        5     Apr-13        5.6                      5.6   1   1-Apr-13
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1   1-Jul-22
# 116    117     Aug-22        3.5                      3.5   1   1-Aug-22
# 117    118     Sep-22        3.5                      3.6   1   1-Sep-22
# 118    119     Oct-22        3.5                      3.4   1   1-Oct-22
# 119    120     Nov-22        3.5                      3.4   1  30-Nov-22
#
# [120 rows x 6 columns]

# %%
# Change to datetime format
data_au_daily['Date']=pd.to_datetime(data_au_daily['Date'])
data_au_daily
# Out:
#      index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day       Date
# 0        1     Dec-12        5.4                      5.4   1 2012-12-01
# 1        2     Jan-13        5.4                      5.4   1 2013-01-01
# 2        3     Feb-13        5.5                      5.4   1 2013-02-01
# 3        4     Mar-13        5.6                      5.6   1 2013-03-01
# 4        5     Apr-13        5.6                      5.6   1 2013-04-01
# ..     ...        ...        ...                      ...  ..        ...
# 115    116     Jul-22        3.6                      3.5   1 2022-07-01
# 116    117     Aug-22        3.5                      3.5   1 2022-08-01
# 117    118     Sep-22        3.5                      3.6   1 2022-09-01
# 118    119     Oct-22        3.5                      3.4   1 2022-10-01
# 119    120     Nov-22        3.5                      3.4   1 2022-11-30
#
# [120 rows x 6 columns]

# %%
# Resample and convert to daily data
new_data_au_daily=data_au_daily.set_index('Date').resample('D').ffill()
new_data_au_daily
# Out:
#             index Unnamed: 0  Trend (%)  Seasonally adjusted (%) Day
# Date
# 2012-12-01      1     Dec-12        5.4                      5.4   1
# 2012-12-02      1     Dec-12        5.4                      5.4   1
# 2012-12-03      1     Dec-12        5.4                      5.4   1
# 2012-12-04      1     Dec-12        5.4                      5.4   1
# 2012-12-05      1     Dec-12        5.4                      5.4   1
# ...           ...        ...        ...                      ...  ..
# 2022-11-26    119     Oct-22        3.5                      3.4   1
# 2022-11-27    119     Oct-22        3.5                      3.4   1
# 2022-11-28    119     Oct-22        3.5                      3.4   1
# 2022-11-29    119     Oct-22        3.5                      3.4   1
# 2022-11-30    120     Nov-22        3.5                      3.4   1
#
# [3652 rows x 5 columns]

# %%
# Check the data
new_data_au_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 2012-12-01 to 2022-11-30
# Freq: D
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    3652 non-null   int64
#  1   Unnamed: 0               3652 non-null   object
#  2   Trend (%)                2922 non-null   float64
#  3   Seasonally adjusted (%)  3652 non-null   float64
#  4   Day                      3652 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 171.2+ KB

# %%
# Drop unnecessary columns
new_data_au_daily=new_data_au_daily.drop(columns=['index','Unnamed: 0','Trend (%)','Day'])
new_data_au_daily
# Out:
#             Seasonally adjusted (%)
# Date
# 2012-12-01                      5.4
# 2012-12-02                      5.4
# 2012-12-03                      5.4
# 2012-12-04                      5.4
# 2012-12-05                      5.4
# ...                             ...
# 2022-11-26                      3.4
# 2022-11-27                      3.4
# 2022-11-28                      3.4
# 2022-11-29                      3.4
# 2022-11-30                      3.4
#
# [3652 rows x 1 columns]

# %%
# Rename the column
new_data_au_daily.columns=['au_unemployment_rate']
new_data_au_daily.head(120)
# Out:
#             au_unemployment_rate
# Date
# 2012-12-01                   5.4
# 2012-12-02                   5.4
# 2012-12-03                   5.4
# 2012-12-04                   5.4
# 2012-12-05                   5.4
# ...                          ...
# 2013-03-26                   5.6
# 2013-03-27                   5.6
# 2013-03-28                   5.6
# 2013-03-29                   5.6
# 2013-03-30                   5.6
#
# [120 rows x 1 columns]

# %% [markdown]
# # Read in USD Index Daily data into dataframe

# %%
# Reading USA Index Daily Data into dataframe from USD_index_data.csv
df_us_index_data = pd.read_csv("USD_index_data.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True,dayfirst=True)                   
df_us_index_data
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2012-12-03   80.180000   80.269997   79.800003   79.879997   79.879997     0.0
# 2012-12-04   79.889999   80.190002   79.610001   79.639999   79.639999     0.0
# 2012-12-05   79.589996   79.919998   79.570000   79.769997   79.769997     0.0
# 2012-12-06   79.800003   80.320000   79.570000   80.260002   80.260002     0.0
# 2012-12-07   80.269997   80.660004   79.730003   80.419998   80.419998     0.0
# ...                ...         ...         ...         ...         ...     ...
# 2022-11-24  105.989998  106.070000  105.629997  105.849998  105.849998     0.0
# 2022-11-25  105.959999  106.419998  105.690002  105.959999  105.959999     0.0
# 2022-11-27         NaN         NaN         NaN         NaN         NaN     NaN
# 2022-11-28  106.059998  106.750000  105.320000  106.680000  106.680000     0.0
# 2022-11-29  106.570000  106.879997  106.059998  106.820000  106.820000     0.0
#
# [3044 rows x 6 columns]

# %%
df_us_index_data=df_us_index_data.dropna()
df_us_index_data=df_us_index_data[['Close']]
df_us_index_data
# Out:
#                  Close
# Date
# 2012-12-03   79.879997
# 2012-12-04   79.639999
# 2012-12-05   79.769997
# 2012-12-06   80.260002
# 2012-12-07   80.419998
# ...                ...
# 2022-11-23  106.080002
# 2022-11-24  105.849998
# 2022-11-25  105.959999
# 2022-11-28  106.680000
# 2022-11-29  106.820000
#
# [2519 rows x 1 columns]

# %%
df_us_index_data=df_us_index_data['2012-12-03':]
df_us_index_data
# Out:
#                  Close
# Date
# 2012-12-03   79.879997
# 2012-12-04   79.639999
# 2012-12-05   79.769997
# 2012-12-06   80.260002
# 2012-12-07   80.419998
# ...                ...
# 2022-11-23  106.080002
# 2022-11-24  105.849998
# 2022-11-25  105.959999
# 2022-11-28  106.680000
# 2022-11-29  106.820000
#
# [2519 rows x 1 columns]

# %%
df_us_index_data.columns=['us_index_daily_data']
df_us_index_data
# Out:
#             us_index_daily_data
# Date
# 2012-12-03            79.879997
# 2012-12-04            79.639999
# 2012-12-05            79.769997
# 2012-12-06            80.260002
# 2012-12-07            80.419998
# ...                         ...
# 2022-11-23           106.080002
# 2022-11-24           105.849998
# 2022-11-25           105.959999
# 2022-11-28           106.680000
# 2022-11-29           106.820000
#
# [2519 rows x 1 columns]

# %% [markdown]
# # Read in AU commodity price index to the dataframe

# %%
# Reading AU commodity price index data into dataframe from AU_Commodity_Price_Index_Data.csv
df_au_comm_index_data = pd.read_csv("AU_Commodity_Price_Index_Data.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True,dayfirst=True)                   
df_au_comm_index_data
# Out:
#             Commodity prices – SDR
# Date
# 2012-12-01                   100.4
# 2013-01-01                   106.3
# 2013-02-01                   108.7
# 2013-03-01                   108.4
# 2013-04-01                   107.2
# ...                            ...
# 2022-07-01                   164.7
# 2022-08-01                   158.4
# 2022-09-01                   168.0
# 2022-10-01                   163.4
# 2022-11-01                   152.6
#
# [120 rows x 1 columns]

# %%
df_au_comm_index_data=df_au_comm_index_data.reset_index()

df_au_comm_index_data
# Out:
#           Date  Commodity prices – SDR
# 0   2012-12-01                   100.4
# 1   2013-01-01                   106.3
# 2   2013-02-01                   108.7
# 3   2013-03-01                   108.4
# 4   2013-04-01                   107.2
# ..         ...                     ...
# 115 2022-07-01                   164.7
# 116 2022-08-01                   158.4
# 117 2022-09-01                   168.0
# 118 2022-10-01                   163.4
# 119 2022-11-01                   152.6
#
# [120 rows x 2 columns]

# %%
df_au_comm_index_data['Date'].iloc[-1]='2022-11-30'
df_au_comm_index_data
# Out:
#           Date  Commodity prices – SDR
# 0   2012-12-01                   100.4
# 1   2013-01-01                   106.3
# 2   2013-02-01                   108.7
# 3   2013-03-01                   108.4
# 4   2013-04-01                   107.2
# ..         ...                     ...
# 115 2022-07-01                   164.7
# 116 2022-08-01                   158.4
# 117 2022-09-01                   168.0
# 118 2022-10-01                   163.4
# 119 2022-11-30                   152.6
#
# [120 rows x 2 columns]

# %%
# Change to datetime format
df_au_comm_index_data['Date']=pd.to_datetime(df_au_comm_index_data['Date'])
df_au_comm_index_data
# Out:
#           Date  Commodity prices – SDR
# 0   2012-12-01                   100.4
# 1   2013-01-01                   106.3
# 2   2013-02-01                   108.7
# 3   2013-03-01                   108.4
# 4   2013-04-01                   107.2
# ..         ...                     ...
# 115 2022-07-01                   164.7
# 116 2022-08-01                   158.4
# 117 2022-09-01                   168.0
# 118 2022-10-01                   163.4
# 119 2022-11-30                   152.6
#
# [120 rows x 2 columns]

# %%
df_au_comm_index_data=df_au_comm_index_data.set_index('Date')
df_au_comm_index_data
# Out:
#             Commodity prices – SDR
# Date
# 2012-12-01                   100.4
# 2013-01-01                   106.3
# 2013-02-01                   108.7
# 2013-03-01                   108.4
# 2013-04-01                   107.2
# ...                            ...
# 2022-07-01                   164.7
# 2022-08-01                   158.4
# 2022-09-01                   168.0
# 2022-10-01                   163.4
# 2022-11-30                   152.6
#
# [120 rows x 1 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_comm_index_data=df_au_comm_index_data.resample('D').ffill()
df_au_comm_index_data
# Out:
#             Commodity prices – SDR
# Date
# 2012-12-01                   100.4
# 2012-12-02                   100.4
# 2012-12-03                   100.4
# 2012-12-04                   100.4
# 2012-12-05                   100.4
# ...                            ...
# 2022-11-26                   163.4
# 2022-11-27                   163.4
# 2022-11-28                   163.4
# 2022-11-29                   163.4
# 2022-11-30                   152.6
#
# [3652 rows x 1 columns]

# %% [markdown]
# # Read in USA inflation rate

# %%
# Reading USA inflation rate from USA_Inflation_Rate.csv
df_us_inflation = pd.read_csv("./Resources/USA_Inflation_Rate.csv",
                             index_col = "Date",
                              infer_datetime_format=True,
                             parse_dates=True)                   
df_us_inflation
# Out:
#               Value
# Date
# 2012-12-01  229.601
# 2012-12-28  229.601
# 2013-01-28  230.280
# 2013-02-28  232.166
# 2013-03-28  232.773
# ...             ...
# 2022-08-28  296.171
# 2022-09-28  296.808
# 2022-10-28  298.012
# 2022-11-28  297.711
# 2022-11-30  297.711
#
# [122 rows x 1 columns]

# %%
#resampling the data with daily with .ffill function  
df_us_inflation_daily=df_us_inflation.resample('D').ffill()
df_us_inflation_daily
# Out:
#               Value
# Date
# 2012-12-01  229.601
# 2012-12-02  229.601
# 2012-12-03  229.601
# 2012-12-04  229.601
# 2012-12-05  229.601
# ...             ...
# 2022-11-26  298.012
# 2022-11-27  298.012
# 2022-11-28  297.711
# 2022-11-29  297.711
# 2022-11-30  297.711
#
# [3652 rows x 1 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_us_inflation_daily = df_us_inflation_daily.loc["2012-12-01":"2022-11-30"]
df_us_inflation_daily
# Out:
#               Value
# Date
# 2012-12-01  229.601
# 2012-12-02  229.601
# 2012-12-03  229.601
# 2012-12-04  229.601
# 2012-12-05  229.601
# ...             ...
# 2022-11-26  298.012
# 2022-11-27  298.012
# 2022-11-28  297.711
# 2022-11-29  297.711
# 2022-11-30  297.711
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_us_inflation_daily.columns=['us_inflation_rate']
df_us_inflation_daily.head(120)
# Out:
#             us_inflation_rate
# Date
# 2012-12-01            229.601
# 2012-12-02            229.601
# 2012-12-03            229.601
# 2012-12-04            229.601
# 2012-12-05            229.601
# ...                       ...
# 2013-03-26            232.166
# 2013-03-27            232.166
# 2013-03-28            232.773
# 2013-03-29            232.773
# 2013-03-30            232.773
#
# [120 rows x 1 columns]

# %%
# Reading USA fed rate from fed-funds-rate-historical-chart.csv

df_us_fed_rate = pd.read_csv("./Resources/fed-funds-rate-historical-chart.csv", 
                             index_col = "date",
                             infer_datetime_format=True,
                             parse_dates=True)

# %%
#resampling the data with daily with .ffill function  
df_us_fed_rate_daily=df_us_fed_rate.resample('D').ffill()
df_us_fed_rate_daily
# Out:
#              value
# date
# 1954-07-01    1.13
# 1954-07-02    1.25
# 1954-07-03    1.25
# 1954-07-04    1.25
# 1954-07-05    0.88
# ...            ...
# 2022-12-18    4.33
# 2022-12-19    4.33
# 2022-12-20    4.33
# 2022-12-21    4.33
# 2022-12-22    4.33
#
# [25012 rows x 1 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_us_fed_rate_daily = df_us_fed_rate_daily.loc["2012-12-1":"2022-11-30"]
df_us_fed_rate_daily
# Out:
#              value
# date
# 2012-12-01    0.16
# 2012-12-02    0.16
# 2012-12-03    0.16
# 2012-12-04    0.17
# 2012-12-05    0.16
# ...            ...
# 2022-11-26    3.83
# 2022-11-27    3.83
# 2022-11-28    3.83
# 2022-11-29    3.83
# 2022-11-30    3.83
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_us_fed_rate_daily.columns=['us_fed_rate']
df_us_fed_rate_daily.head(120)
# Out:
#             us_fed_rate
# date
# 2012-12-01         0.16
# 2012-12-02         0.16
# 2012-12-03         0.16
# 2012-12-04         0.17
# 2012-12-05         0.16
# ...                 ...
# 2013-03-26         0.14
# 2013-03-27         0.12
# 2013-03-28         0.13
# 2013-03-29         0.09
# 2013-03-30         0.09
#
# [120 rows x 1 columns]

# %%
# Reading AU inflation rate from AU_Inflation.csv file
df_au_inflation_rate = pd.read_csv("./Resources/AU_Inflation.csv",
                            index_col = "Date",
                             infer_datetime_format=True,
                             parse_dates=True)
df_au_inflation_rate
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-12-01          7.8         NaN
# 1990-03-01          8.7         NaN
# 1990-06-01          7.7         NaN
# 1990-09-01          6.1         NaN
# ...                 ...         ...
# 2022-09-21          3.0         2.1
# 2022-12-21          3.5         2.6
# 2022-03-22          5.1         3.7
# 2022-06-22          6.1         4.9
# 2022-09-22          7.3         6.1
#
# [133 rows x 2 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_inflation_rate_daily=df_au_inflation_rate.resample('D').ffill()
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 1989-09-01          8.0         NaN
# 1989-09-02          8.0         NaN
# 1989-09-03          8.0         NaN
# 1989-09-04          8.0         NaN
# 1989-09-05          8.0         NaN
# ...                 ...         ...
# 2022-12-17          1.9         1.7
# 2022-12-18          1.8         1.8
# 2022-12-19          1.8         1.5
# 2022-12-20          0.9         1.2
# 2022-12-21          3.5         2.6
#
# [12165 rows x 2 columns]

# %%
# selected data range from 2012-12-01  to 2022-11-30
df_au_inflation_rate_daily = df_au_inflation_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_inflation_rate_daily
# Out:
#             Inflation %  Unnamed: 2
# Date
# 2012-12-01          5.8         NaN
# 2012-12-02          5.8         NaN
# 2012-12-03          5.8         NaN
# 2012-12-04          5.8         NaN
# 2012-12-05          5.8         NaN
# ...                 ...         ...
# 2022-11-26          7.3         6.1
# 2022-11-27          7.3         6.1
# 2022-11-28          7.3         6.1
# 2022-11-29          7.3         6.1
# 2022-11-30          7.3         6.1
#
# [3652 rows x 2 columns]

# %%
df_au_inflation_rate_daily = df_au_inflation_rate_daily.drop(columns = ["Unnamed: 2"])
df_au_inflation_rate_daily
# Out:
#             Inflation %
# Date
# 2012-12-01          5.8
# 2012-12-02          5.8
# 2012-12-03          5.8
# 2012-12-04          5.8
# 2012-12-05          5.8
# ...                 ...
# 2022-11-26          7.3
# 2022-11-27          7.3
# 2022-11-28          7.3
# 2022-11-29          7.3
# 2022-11-30          7.3
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_inflation_rate_daily.columns=['au_inflation_rate']
df_au_inflation_rate_daily.head(120)
# Out:
#             au_inflation_rate
# Date
# 2012-12-01                5.8
# 2012-12-02                5.8
# 2012-12-03                5.8
# 2012-12-04                5.8
# 2012-12-05                5.8
# ...                       ...
# 2013-03-26                5.8
# 2013-03-27                5.8
# 2013-03-28                5.8
# 2013-03-29                5.8
# 2013-03-30                5.8
#
# [120 rows x 1 columns]

# %%
# Reading AU cash rate from AU_Cashrate.csv
df_au_cash_rate = pd.read_csv("./Resources/AU_Cashrate.csv",
                              index_col ="Date",
                              infer_datetime_format=True, 
                              parse_dates = True)
df_au_cash_rate
# Out:
#             Cash Rate Target on date
# Date
# 2011-01-04                      4.75
# 2011-01-05                      4.75
# 2011-01-06                      4.75
# 2011-01-07                      4.75
# 2011-01-10                      4.75
# ...                              ...
# 2022-12-22                      3.10
# 2022-12-23                      3.10
# 2022-12-28                      3.10
# 2022-12-29                      3.10
# 2022-12-30                       NaN
#
# [3036 rows x 1 columns]

# %%
#resampling the data with daily with .ffill function  
df_au_cash_rate_daily=df_au_cash_rate.resample('D').ffill()

# %%
# selected data range from 2012-12-01 to 2022-11-30
df_au_cash_rate_daily = df_au_cash_rate_daily.loc["2012-12-1":"2022-11-30"]
df_au_cash_rate_daily
# Out:
#             Cash Rate Target on date
# Date
# 2012-12-01                      3.25
# 2012-12-02                      3.25
# 2012-12-03                      3.25
# 2012-12-04                      3.25
# 2012-12-05                      3.00
# ...                              ...
# 2022-11-26                      2.85
# 2022-11-27                      2.85
# 2022-11-28                      2.85
# 2022-11-29                      2.85
# 2022-11-30                      2.85
#
# [3652 rows x 1 columns]

# %%
# Rename the column
df_au_cash_rate_daily.columns=['au_cash_rate']
df_au_cash_rate_daily.head(120)
# Out:
#             au_cash_rate
# Date
# 2012-12-01          3.25
# 2012-12-02          3.25
# 2012-12-03          3.25
# 2012-12-04          3.25
# 2012-12-05          3.00
# ...                  ...
# 2013-03-26          3.00
# 2013-03-27          3.00
# 2013-03-28          3.00
# 2013-03-29          3.00
# 2013-03-30          3.00
#
# [120 rows x 1 columns]

# %%
# Concatenating all the data into one dataframe
all_df_daily = pd.concat([close_daily, new_df3_us_daily, new_data_au_daily, df_us_inflation_daily, df_au_inflation_rate_daily, df_us_fed_rate_daily, df_au_cash_rate_daily,df_us_index_data,df_au_comm_index_data], axis="columns", join="inner")
all_df_daily
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-03  1.04220                   7.9                   5.4
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-03            229.601                5.8         0.16          3.25
# 2012-12-04            229.601                5.8         0.17          3.25
# 2012-12-05            229.601                5.8         0.16          3.00
# 2012-12-06            229.601                5.8         0.16          3.00
# 2012-12-07            229.601                5.8         0.16          3.00
# ...                       ...                ...          ...           ...
# 2022-11-23            298.012                7.3         3.83          2.85
# 2022-11-24            298.012                7.3         3.83          2.85
# 2022-11-25            298.012                7.3         3.83          2.85
# 2022-11-28            297.711                7.3         3.83          2.85
# 2022-11-29            297.711                7.3         3.83          2.85
#
#             us_index_daily_data  Commodity prices – SDR
# 2012-12-03            79.879997                   100.4
# 2012-12-04            79.639999                   100.4
# 2012-12-05            79.769997                   100.4
# 2012-12-06            80.260002                   100.4
# 2012-12-07            80.419998                   100.4
# ...                         ...                     ...
# 2022-11-23           106.080002                   163.4
# 2022-11-24           105.849998                   163.4
# 2022-11-25           105.959999                   163.4
# 2022-11-28           106.680000                   163.4
# 2022-11-29           106.820000                   163.4
#
# [2519 rows x 9 columns]

# %%
# all_df_daily['au/us unemployment ratio']=all_df_daily['au_unemployment_rate']/all_df_daily['us_unemployment_rate']

# %%
# all_df_daily['au/us inflation ratio']=all_df_daily['au_inflation_rate']/all_df_daily['us_inflation_rate']

# %%
# all_df_daily['au/us interest ratio']=all_df_daily['au_cash_rate']/all_df_daily['us_fed_rate']

# %%
all_df_daily
# Out:
#               close  us_unemployment_rate  au_unemployment_rate  \
# 2012-12-03  1.04220                   7.9                   5.4
# 2012-12-04  1.04710                   7.9                   5.4
# 2012-12-05  1.04560                   7.9                   5.4
# 2012-12-06  1.04870                   7.9                   5.4
# 2012-12-07  1.04890                   7.9                   5.4
# ...             ...                   ...                   ...
# 2022-11-23  0.67351                   3.7                   3.4
# 2022-11-24  0.67646                   3.7                   3.4
# 2022-11-25  0.67524                   3.7                   3.4
# 2022-11-28  0.66524                   3.7                   3.4
# 2022-11-29  0.66879                   3.7                   3.4
#
#             us_inflation_rate  au_inflation_rate  us_fed_rate  au_cash_rate  \
# 2012-12-03            229.601                5.8         0.16          3.25
# 2012-12-04            229.601                5.8         0.17          3.25
# 2012-12-05            229.601                5.8         0.16          3.00
# 2012-12-06            229.601                5.8         0.16          3.00
# 2012-12-07            229.601                5.8         0.16          3.00
# ...                       ...                ...          ...           ...
# 2022-11-23            298.012                7.3         3.83          2.85
# 2022-11-24            298.012                7.3         3.83          2.85
# 2022-11-25            298.012                7.3         3.83          2.85
# 2022-11-28            297.711                7.3         3.83          2.85
# 2022-11-29            297.711                7.3         3.83          2.85
#
#             us_index_daily_data  Commodity prices – SDR
# 2012-12-03            79.879997                   100.4
# 2012-12-04            79.639999                   100.4
# 2012-12-05            79.769997                   100.4
# 2012-12-06            80.260002                   100.4
# 2012-12-07            80.419998                   100.4
# ...                         ...                     ...
# 2022-11-23           106.080002                   163.4
# 2022-11-24           105.849998                   163.4
# 2022-11-25           105.959999                   163.4
# 2022-11-28           106.680000                   163.4
# 2022-11-29           106.820000                   163.4
#
# [2519 rows x 9 columns]

# %%
# ml_ready_df = all_df_daily.copy().drop(columns=["us_unemployment_rate", "au_unemployment_rate", "us_inflation_rate", "au_inflation_rate", "us_fed_rate", "au_cash_rate"])
# ml_ready_df

# %% [markdown]
# ### Create the labels set (`y`)  from the “close” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = all_df_daily['close']

# Separate the X variable, the features
X = all_df_daily.copy().drop(columns = 'close')

# %%
# Review the y variable Series
y[0:5]
# Out:
# 2012-12-03    1.0422
# 2012-12-04    1.0471
# 2012-12-05    1.0456
# 2012-12-06    1.0487
# 2012-12-07    1.0489
# Name: close, dtype: float64

# %%
# Review the X variable DataFrame
X
# Out:
#             us_unemployment_rate  au_unemployment_rate  us_inflation_rate  \
# 2012-12-03                   7.9                   5.4            229.601
# 2012-12-04                   7.9                   5.4            229.601
# 2012-12-05                   7.9                   5.4            229.601
# 2012-12-06                   7.9                   5.4            229.601
# 2012-12-07                   7.9                   5.4            229.601
# ...                          ...                   ...                ...
# 2022-11-23                   3.7                   3.4            298.012
# 2022-11-24                   3.7                   3.4            298.012
# 2022-11-25                   3.7                   3.4            298.012
# 2022-11-28                   3.7                   3.4            297.711
# 2022-11-29                   3.7                   3.4            297.711
#
#             au_inflation_rate  us_fed_rate  au_cash_rate  us_index_daily_data  \
# 2012-12-03                5.8         0.16          3.25            79.879997
# 2012-12-04                5.8         0.17          3.25            79.639999
# 2012-12-05                5.8         0.16          3.00            79.769997
# 2012-12-06                5.8         0.16          3.00            80.260002
# 2012-12-07                5.8         0.16          3.00            80.419998
# ...                       ...          ...           ...                  ...
# 2022-11-23                7.3         3.83          2.85           106.080002
# 2022-11-24                7.3         3.83          2.85           105.849998
# 2022-11-25                7.3         3.83          2.85           105.959999
# 2022-11-28                7.3         3.83          2.85           106.680000
# 2022-11-29                7.3         3.83          2.85           106.820000
#
#             Commodity prices – SDR
# 2012-12-03                   100.4
# 2012-12-04                   100.4
# 2012-12-05                   100.4
# 2012-12-06                   100.4
# 2012-12-07                   100.4
# ...                            ...
# 2022-11-23                   163.4
# 2022-11-24                   163.4
# 2022-11-25                   163.4
# 2022-11-28                   163.4
# 2022-11-29                   163.4
#
# [2519 rows x 8 columns]

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)

# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(years=8)

# Display the training end date
print(training_end)


# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train
# Out:
# 2012-12-03 00:00:00
# 2020-12-03 00:00:00
#             us_unemployment_rate  au_unemployment_rate  us_inflation_rate  \
# 2012-12-03                   7.9                   5.4            229.601
# 2012-12-04                   7.9                   5.4            229.601
# 2012-12-05                   7.9                   5.4            229.601
# 2012-12-06                   7.9                   5.4            229.601
# 2012-12-07                   7.9                   5.4            229.601
# ...                          ...                   ...                ...
# 2020-11-27                   6.7                   6.8            260.388
# 2020-11-30                   6.7                   6.8            260.229
# 2020-12-01                   6.7                   6.6            260.229
# 2020-12-02                   6.7                   6.6            260.229
# 2020-12-03                   6.7                   6.6            260.229
#
#             au_inflation_rate  us_fed_rate  au_cash_rate  us_index_daily_data  \
# 2012-12-03                5.8         0.16          3.25            79.879997
# 2012-12-04                5.8         0.17          3.25            79.639999
# 2012-12-05                5.8         0.16          3.00            79.769997
# 2012-12-06                5.8         0.16          3.00            80.260002
# 2012-12-07                5.8         0.16          3.00            80.419998
# ...                       ...          ...           ...                  ...
# 2020-11-27                5.8         0.08          0.10            91.790001
# 2020-11-30                5.8         0.09          0.10            91.870003
# 2020-12-01                5.8         0.09          0.10            91.309998
# 2020-12-02                5.8         0.09          0.10            91.120003
# 2020-12-03                5.8         0.09          0.10            90.709999
#
#             Commodity prices – SDR
# 2012-12-03                   100.4
# 2012-12-04                   100.4
# 2012-12-05                   100.4
# 2012-12-06                   100.4
# 2012-12-07                   100.4
# ...                            ...
# 2020-11-27                    88.7
# 2020-11-30                    88.7
# 2020-12-01                    97.6
# 2020-12-02                    97.6
# 2020-12-03                    97.6
#
# [2015 rows x 8 columns]

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(days=1):]
y_test = y.loc[training_end+DateOffset(days=1):]


# Review the X_test DataFrame
X_test
# Out:
#             us_unemployment_rate  au_unemployment_rate  us_inflation_rate  \
# 2020-12-04                   6.7                   6.6            260.229
# 2020-12-07                   6.7                   6.6            260.229
# 2020-12-08                   6.7                   6.6            260.229
# 2020-12-09                   6.7                   6.6            260.229
# 2020-12-10                   6.7                   6.6            260.229
# ...                          ...                   ...                ...
# 2022-11-23                   3.7                   3.4            298.012
# 2022-11-24                   3.7                   3.4            298.012
# 2022-11-25                   3.7                   3.4            298.012
# 2022-11-28                   3.7                   3.4            297.711
# 2022-11-29                   3.7                   3.4            297.711
#
#             au_inflation_rate  us_fed_rate  au_cash_rate  us_index_daily_data  \
# 2020-12-04                5.8         0.09          0.10            90.699997
# 2020-12-07                5.8         0.09          0.10            90.790001
# 2020-12-08                5.8         0.09          0.10            90.970001
# 2020-12-09                5.8         0.09          0.10            91.089996
# 2020-12-10                5.8         0.09          0.10            90.790001
# ...                       ...          ...           ...                  ...
# 2022-11-23                7.3         3.83          2.85           106.080002
# 2022-11-24                7.3         3.83          2.85           105.849998
# 2022-11-25                7.3         3.83          2.85           105.959999
# 2022-11-28                7.3         3.83          2.85           106.680000
# 2022-11-29                7.3         3.83          2.85           106.820000
#
#             Commodity prices – SDR
# 2020-12-04                    97.6
# 2020-12-07                    97.6
# 2020-12-08                    97.6
# 2020-12-09                    97.6
# 2020-12-10                    97.6
# ...                            ...
# 2022-11-23                   163.4
# 2022-11-24                   163.4
# 2022-11-25                   163.4
# 2022-11-28                   163.4
# 2022-11-29                   163.4
#
# [504 rows x 8 columns]

# %%
y_test
# Out:
# 2020-12-04    0.74267
# 2020-12-07    0.74212
# 2020-12-08    0.74098
# 2020-12-09    0.74433
# 2020-12-10    0.75354
#                ...
# 2022-11-23    0.67351
# 2022-11-24    0.67646
# 2022-11-25    0.67524
# 2022-11-28    0.66524
# 2022-11-29    0.66879
# Name: close, Length: 504, dtype: float64

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
X_scaler = scaler.fit(X_train)

# %%
# Transform the X_train and X_test DataFrames using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 0.62282845,  1.67463608,  1.77892441, ..., -2.20000873,
#         -0.25883849,  1.1466555 ],
#        [ 0.62282845,  1.67463608,  1.77892441, ..., -2.20000873,
#         -0.24560142,  1.1466555 ],
#        [ 0.62282845,  1.67463608,  1.77892441, ..., -2.20000873,
#         -0.21912845,  1.1466555 ],
#        ...,
#        [-0.90337771, -4.59455427,  5.95145567, ...,  1.52766518,
#          1.98548122,  6.32814415],
#        [-0.90337771, -4.59455427,  5.91821501, ...,  1.52766518,
#          2.09137324,  6.32814415],
#        [-0.90337771, -4.59455427,  5.91821501, ...,  1.52766518,
#          2.11196333,  6.32814415]])

# %%
# creating a regression model
model = LinearRegression()

# %%
# fitting the model
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# making predictions
predictions = model.predict(X_test_scaled)
predictions
# Out:
# array([0.74879866, 0.74820587, 0.74702034, 0.74623002, 0.74820587,
#        0.74695446, 0.74873278, 0.75031347, 0.75044523, 0.75459456,
#        0.75327732, 0.75314557, 0.74912794, 0.75070863, 0.75123555,
#        0.75038628, 0.75255971, 0.75506253, 0.75302075, 0.76816693,
#        0.77106485, 0.77047211, 0.76849621, 0.76671794, 0.76381996,
#        0.76704722, 0.76526895, 0.76579586, 0.76223927, 0.76408342,
#        0.764281  , 0.76668159, 0.7659571 , 0.76496915, 0.76641814,
#        0.7632567 , 0.76112629, 0.76033592, 0.7619872 , 0.76080167,
#        0.76132853, 0.75862819, 0.76185544, 0.76274118, 0.7658072 ,
#        0.76626823, 0.76593895, 0.76554374, 0.76534616, 0.76244823,
#        0.76498053, 0.76649534, 0.76880053, 0.76774675, 0.76768088,
#        0.76801021, 0.76274118, 0.76517621, 0.76682278, 0.765769  ,
#        0.76129034, 0.7589851 , 0.75681167, 0.75911686, 0.76023651,
#        0.76267345, 0.760961  , 0.75997305, 0.75970959, 0.76280515,
#        0.75984135, 0.75938031, 0.76017063, 0.75661409, 0.75536268,
#        0.7530575 , 0.75378199, 0.74670497, 0.7443339 , 0.74495618,
#        0.75457328, 0.75674676, 0.75845921, 0.75766884, 0.76030335,
#        0.75964468, 0.75977644, 0.76168647, 0.76274024, 0.76287199,
#        0.76359648, 0.76682374, 0.76570409, 0.76623095, 0.7651113 ,
#        0.76820685, 0.76853619, 0.76787752, 0.76289201, 0.76305325,
#        0.7588017 , 0.77483975, 0.7726004 , 0.77246869, 0.77483975,
#        0.77958183, 0.77971358, 0.78017462, 0.77642045, 0.77615699,
#        0.77898908, 0.7796477 , 0.78274326, 0.77984528, 0.78234809,
#        0.78096498, 0.78221634, 0.78346775, 0.78083323, 0.78129427,
#        0.77421405, 0.79282352, 0.79236248, 0.78841074, 0.7907818 ,
#        0.7920332 , 0.79117696, 0.7909135 , 0.79117696, 0.78801557,
#        0.78827903, 0.78814728, 0.78426141, 0.77861088, 0.77637153,
#        0.77880846, 0.77966466, 0.77920362, 0.77907192, 0.77913779,
#        0.7706793 , 0.76955959, 0.76731342, 0.7771405 , 0.77957738,
#        0.77746978, 0.77687704, 0.77872118, 0.78023605, 0.77957738,
#        0.77615254, 0.77839185, 0.77700874, 0.77654771, 0.77523047,
#        0.77470356, 0.77615254, 0.77569151, 0.77509872, 0.77681116,
#        0.77826015, 0.77480524, 0.77783491, 0.7762769 , 0.75576618,
#        0.75556859, 0.75431724, 0.75451482, 0.75082647, 0.74983857,
#        0.74911408, 0.75010198, 0.74924578, 0.75267067, 0.75194618,
#        0.74865305, 0.74874841, 0.7459163 , 0.74637734, 0.74993393,
#        0.75039497, 0.75079013, 0.74927531, 0.75187344, 0.75033339,
#        0.75078762, 0.7367964 , 0.73824534, 0.73949675, 0.73633536,
#        0.73547912, 0.73659878, 0.73594016, 0.7356767 , 0.73547912,
#        0.73653295, 0.73409601, 0.7318567 , 0.73159324, 0.7318567 ,
#        0.73014426, 0.73251532, 0.73100045, 0.73067117, 0.72572663,
#        0.72197247, 0.72288768, 0.73906331, 0.74057818, 0.73945848,
#        0.7375485 , 0.73787779, 0.73886573, 0.73721917, 0.73590193,
#        0.73879986, 0.73959023, 0.73972193, 0.7396561 , 0.74070988,
#        0.74222474, 0.74084163, 0.74189541, 0.74057818, 0.7396561 ,
#        0.74024884, 0.73632029, 0.73141006, 0.74701999, 0.74563688,
#        0.74715169, 0.74392444, 0.74412201, 0.74590029, 0.74649308,
#        0.7406313 , 0.73845782, 0.73878715, 0.73694295, 0.733584  ,
#        0.73417673, 0.73608676, 0.73259604, 0.72976395, 0.72982982,
#        0.72752464, 0.73246434, 0.72647209, 0.72893851, 0.72912112,
#        0.72859426, 0.72866008, 0.72754043, 0.72701352, 0.73017495,
#        0.72767218, 0.72912112, 0.72734285, 0.72569628, 0.72609144,
#        0.729187  , 0.72569628, 0.72582799, 0.7262232 , 0.72892354,
#        0.72931875, 0.72885772, 0.72540238, 0.72718065, 0.72691719,
#        0.72905433, 0.74539454, 0.74506521, 0.74572383, 0.74532866,
#        0.74868767, 0.74704111, 0.74947799, 0.7535615 , 0.75494461,
#        0.75244185, 0.7487535 , 0.75020249, 0.74868767, 0.74934629,
#        0.74750215, 0.74730456, 0.74374797, 0.73867652, 0.73110887,
#        0.73591682, 0.75441443, 0.75737823, 0.76106657, 0.76040791,
#        0.76093482, 0.75935413, 0.76034208, 0.75994687, 0.75645615,
#        0.75454613, 0.75704894, 0.75895897, 0.7583003 , 0.75671961,
#        0.75678549, 0.75573166, 0.74947473, 0.75289956, 0.74409511,
#        0.77433939, 0.77447115, 0.77183663, 0.76617243, 0.76195723,
#        0.76347209, 0.7706511 , 0.76709451, 0.76307688, 0.76347209,
#        0.76340621, 0.76795076, 0.76635674, 0.76490775, 0.76312948,
#        0.76319536, 0.76233911, 0.76121946, 0.76108775, 0.7471307 ,
#        0.75167518, 0.75569281, 0.75226797, 0.78560869, 0.78323763,
#        0.7800762 , 0.77922   , 0.77823205, 0.77790272, 0.77704652,
#        0.77467546, 0.77737585, 0.77447788, 0.7714482 , 0.77026267,
#        0.77401684, 0.77276543, 0.76855023, 0.76505951, 0.76143704,
#        0.75715601, 0.74761085, 0.75195781, 0.73409549, 0.73587377,
#        0.74778691, 0.732085  , 0.73267774, 0.73274361, 0.73096535,
#        0.73142639, 0.72484012, 0.72675013, 0.72918703, 0.73465364,
#        0.73168984, 0.73886885, 0.73603675, 0.74308405, 0.74453304,
#        0.74321581, 0.74473062, 0.74578445, 0.73756921, 0.73506645,
#        0.73275261, 0.73788994, 0.73545301, 0.73347711, 0.73426747,
#        0.74505287, 0.74057421, 0.73444897, 0.72832374, 0.72542582,
#        0.72779683, 0.72578115, 0.71873384, 0.72018278, 0.72044624,
#        0.72202697, 0.72051211, 0.7220928 , 0.72373937, 0.70714641,
#        0.70319465, 0.70596088, 0.68902862, 0.68869929, 0.68007129,
#        0.68835393, 0.68815635, 0.68894667, 0.68229457, 0.68196524,
#        0.68268973, 0.67886968, 0.68203111, 0.6865756 , 0.69112015,
#        0.68848563, 0.68960528, 0.69079082, 0.69243738, 0.68776114,
#        0.69263501, 0.68131283, 0.68443786, 0.67253414, 0.66733099,
#        0.67778705, 0.68318779, 0.67706256, 0.67824809, 0.67870912,
#        0.6864151 , 0.68713959, 0.683583  , 0.6775236 , 0.67785293,
#        0.67739189, 0.67139837, 0.66685387, 0.66105792, 0.66389002,
#        0.66349486, 0.66487797, 0.66270449, 0.66277685, 0.66323788,
#        0.66369892, 0.67945885, 0.68051267, 0.67603401, 0.69070534,
#        0.69156153, 0.69623777, 0.70065056, 0.69083703, 0.69189081,
#        0.69136395, 0.6912322 , 0.69136395, 0.68820252, 0.6854363 ,
#        0.66866734, 0.65654858, 0.6505551 , 0.65048922, 0.65839756,
#        0.66070274, 0.66155894, 0.65300179, 0.66406672, 0.66359765,
#        0.65575998, 0.65220338, 0.64996408, 0.64943716, 0.64877854,
#        0.65510136, 0.64884442, 0.65720896, 0.65661622, 0.65101786,
#        0.65167652, 0.65740654, 0.65753829, 0.66438802, 0.67262086,
#        0.66675908, 0.66238213, 0.65671793, 0.65704722, 0.66402066,
#        0.64152162, 0.65502349, 0.66002902, 0.66332215, 0.65719692,
#        0.67260882, 0.68525444, 0.6828175 , 0.68452994, 0.68532032,
#        0.68261993, 0.68103923, 0.67504576, 0.67912921, 0.68663755,
#        0.68815242, 0.68742792, 0.68364831, 0.68272623])

# %%
df_predictions = pd.DataFrame(predictions)
df_predictions
# Out:
#             0
# 0    0.748799
# 1    0.748206
# 2    0.747020
# 3    0.746230
# 4    0.748206
# ..        ...
# 499  0.686638
# 500  0.688152
# 501  0.687428
# 502  0.683648
# 503  0.682726
#
# [504 rows x 1 columns]

# %%
df_predictions.index=y_test.index
df_predictions
# Out:
#                    0
# 2020-12-04  0.748799
# 2020-12-07  0.748206
# 2020-12-08  0.747020
# 2020-12-09  0.746230
# 2020-12-10  0.748206
# ...              ...
# 2022-11-23  0.686638
# 2022-11-24  0.688152
# 2022-11-25  0.687428
# 2022-11-28  0.683648
# 2022-11-29  0.682726
#
# [504 rows x 1 columns]

# %%
print(f"R-squared of training data is: {model.score(X_train_scaled, y_train)}")
print(f"R-squared of testing data is: {model.score(X_test_scaled, y_test)}")
# Out:
# R-squared of training data is: 0.9334757837239385
# R-squared of testing data is: 0.6964848749680035

# %%
y_test
# Out:
# 2020-12-04    0.74267
# 2020-12-07    0.74212
# 2020-12-08    0.74098
# 2020-12-09    0.74433
# 2020-12-10    0.75354
#                ...
# 2022-11-23    0.67351
# 2022-11-24    0.67646
# 2022-11-25    0.67524
# 2022-11-28    0.66524
# 2022-11-29    0.66879
# Name: close, Length: 504, dtype: float64

# %%
df_y_test=y_test.to_frame()

df_y_test
# Out:
#               close
# 2020-12-04  0.74267
# 2020-12-07  0.74212
# 2020-12-08  0.74098
# 2020-12-09  0.74433
# 2020-12-10  0.75354
# ...             ...
# 2022-11-23  0.67351
# 2022-11-24  0.67646
# 2022-11-25  0.67524
# 2022-11-28  0.66524
# 2022-11-29  0.66879
#
# [504 rows x 1 columns]

# %%
# Create a new empty predictions DataFrame.

predictions_df=pd.DataFrame({})

# Create a predictions DataFrame
predictions_df.index=df_y_test.index

predictions_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-12-04 00:00:00, 2020-12-07 00:00:00, 2020-12-08 00:00:00, 2020-12-09 00:00:00, 2020-12-10 00:00:00, 2020-12-11 00:00:00, 2020-12-14 00:00:00, 2020-12-15 00:00:00, 2020-12-16 00:00:00, 2020-12-17 00:00:00, 2020-12-18 00:00:00, 2020-12-21 00:00:00, 2020-12-22 00:00:00, 2020-12-23 00:00:00, 2020-12-24 00:00:00, 2020-12-28 00:00:00, 2020-12-29 00:00:00, 2020-12-30 00:00:00, 2020-12-31 00:00:00, 2021-01-04 00:00:00, 2021-01-05 00:00:00, 2021-01-06 00:00:00, 2021-01-07 00:00:00, 2021-01-08 00:00:00, 2021-01-11 00:00:00, 2021-01-12 00:00:00, 2021-01-13 00:00:00, 2021-01-14 00:00:00, 2021-01-15 00:00:00, 2021-01-19 00:00:00, 2021-01-20 00:00:00, 2021-01-21 00:00:00, 2021-01-22 00:00:00, 2021-01-25 00:00:00, 2021-01-26 00:00:00, 2021-01-27 00:00:00, 2021-01-28 00:00:00, 2021-01-29 00:00:00, 2021-02-01 00:00:00, 2021-02-02 00:00:00, 2021-02-03 00:00:00, 2021-02-04 00:00:00, 2021-02-05 00:00:00, 2021-02-08 00:00:00, 2021-02-09 00:00:00, 2021-02-10 00:00:00, 2021-02-11 00:00:00, 2021-02-12 00:00:00, 2021-02-16 00:00:00, 2021-02-17 00:00:00, 2021-02-18 00:00:00, 2021-02-19 00:00:00, 2021-02-22 00:00:00, 2021-02-23 00:00:00, 2021-02-24 00:00:00, 2021-02-25 00:00:00, 2021-02-26 00:00:00, 2021-03-01 00:00:00, 2021-03-02 00:00:00, 2021-03-03 00:00:00, 2021-03-04 00:00:00, 2021-03-05 00:00:00, 2021-03-08 00:00:00, 2021-03-09 00:00:00, 2021-03-10 00:00:00, 2021-03-11 00:00:00, 2021-03-12 00:00:00, 2021-03-15 00:00:00, 2021-03-16 00:00:00, 2021-03-17 00:00:00, 2021-03-18 00:00:00, 2021-03-19 00:00:00, 2021-03-22 00:00:00, 2021-03-23 00:00:00, 2021-03-24 00:00:00, 2021-03-25 00:00:00, 2021-03-26 00:00:00, 2021-03-29 00:00:00, 2021-03-30 00:00:00, 2021-03-31 00:00:00, 2021-04-01 00:00:00, 2021-04-05 00:00:00, 2021-04-06 00:00:00, 2021-04-07 00:00:00, 2021-04-08 00:00:00, 2021-04-09 00:00:00, 2021-04-12 00:00:00, 2021-04-13 00:00:00, 2021-04-14 00:00:00, 2021-04-15 00:00:00, 2021-04-16 00:00:00, 2021-04-19 00:00:00, 2021-04-20 00:00:00, 2021-04-21 00:00:00, 2021-04-22 00:00:00, 2021-04-23 00:00:00, 2021-04-26 00:00:00, 2021-04-27 00:00:00, 2021-04-28 00:00:00, 2021-04-29 00:00:00, ...]
#
# [504 rows x 0 columns]

# %%
predictions_df['predictions']=df_predictions

predictions_df
# Out:
#             predictions
# 2020-12-04     0.748799
# 2020-12-07     0.748206
# 2020-12-08     0.747020
# 2020-12-09     0.746230
# 2020-12-10     0.748206
# ...                 ...
# 2022-11-23     0.686638
# 2022-11-24     0.688152
# 2022-11-25     0.687428
# 2022-11-28     0.683648
# 2022-11-29     0.682726
#
# [504 rows x 1 columns]

# %%
predictions_df['actuals']=df_y_test['close']

predictions_df
# Out:
#             predictions  actuals
# 2020-12-04     0.748799  0.74267
# 2020-12-07     0.748206  0.74212
# 2020-12-08     0.747020  0.74098
# 2020-12-09     0.746230  0.74433
# 2020-12-10     0.748206  0.75354
# ...                 ...      ...
# 2022-11-23     0.686638  0.67351
# 2022-11-24     0.688152  0.67646
# 2022-11-25     0.687428  0.67524
# 2022-11-28     0.683648  0.66524
# 2022-11-29     0.682726  0.66879
#
# [504 rows x 2 columns]

# %%
predictions_df.plot()
# Out:
# <AxesSubplot:>
